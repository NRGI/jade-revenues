# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_csv('data/2014-15_gems_jade.csv')

# %%
# df = df[df['country'] == "Myanmar"]

# %%
df.head()
# Out:
#    Unnamed: 0                            company_name  \
# 0           0  Myanmar Win Gate Gems Jewellery Mining
# 1           0  Myanmar Win Gate Gems Jewellery Mining
# 2           0  Myanmar Win Gate Gems Jewellery Mining
# 3           0  Myanmar Win Gate Gems Jewellery Mining
# 4           0  Myanmar Win Gate Gems Jewellery Mining
#
#        name_of_revenue_stream                  paid_to  value_reported
# 0                  Sale Split  Myanmar Gems Enterprise    2.201612e+10
# 1             Sales Royalties  Myanmar Gems Enterprise    4.368923e+09
# 2               Emporium Fees         Central Comittee    5.617191e+08
# 3  Other significant payments  Myanmar Gems Enterprise    0.000000e+00
# 4        Production Royalties  Myanmar Gems Enterprise    0.000000e+00

# %% [markdown]
# ## Clean data

# %%
df_gemsjade = df

df_gemsjade.rename(columns={'company_name': 'Company_name_cl'}, inplace=True)

df_gemsjade['type'] = 'entity'
df_gemsjade['target_type'] = ''

# %%
df_gemsjade.head()
# Out:
#    Unnamed: 0                         Company_name_cl  \
# 0           0  Myanmar Win Gate Gems Jewellery Mining
# 1           0  Myanmar Win Gate Gems Jewellery Mining
# 2           0  Myanmar Win Gate Gems Jewellery Mining
# 3           0  Myanmar Win Gate Gems Jewellery Mining
# 4           0  Myanmar Win Gate Gems Jewellery Mining
#
#        name_of_revenue_stream                  paid_to  value_reported  \
# 0                  Sale Split  Myanmar Gems Enterprise    2.201612e+10
# 1             Sales Royalties  Myanmar Gems Enterprise    4.368923e+09
# 2               Emporium Fees         Central Comittee    5.617191e+08
# 3  Other significant payments  Myanmar Gems Enterprise    0.000000e+00
# 4        Production Royalties  Myanmar Gems Enterprise    0.000000e+00
#
#      type target_type
# 0  entity
# 1  entity
# 2  entity
# 3  entity
# 4  entity

# %%
append_dict_others = [{'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity', 
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Production Royalties', 'value_reported': 4397493510 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Sale Split', 'value_reported': 7636322539 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Sales Royalties', 'value_reported': 28379373647 },

                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Service Fees', 'value_reported': 12162588706 },
                     
                      {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Permit Fees', 'value_reported': 72073329715 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Incentive Fees', 'value_reported': 185070361 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Other significant payments', 'value_reported': 3645329861 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Emporium Fees / Sale Fees', 'value_reported': 5360554108 },
    
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Customs Department',
                       'name_of_revenue_stream': 'Customs Duties', 'value_reported': 4822220928 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Commercial Tax', 'value_reported':   4569416181 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Royalties', 'value_reported':  22350747468 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Income Tax', 'value_reported':  2091258147 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Withholding Tax', 'value_reported':  616601787 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Capital Gains Tax', 'value_reported':  2860000 }
                     ]

others_df = pd.DataFrame(append_dict_others)
#others_df['total_payments'] = others_df['value_reported']
df_gemsjade = pd.concat([df_gemsjade, others_df])
df_gemsjade
# Out:
#                             Company_name_cl  Unnamed: 0  \
# 0    Myanmar Win Gate Gems Jewellery Mining         0.0
# 1    Myanmar Win Gate Gems Jewellery Mining         0.0
# 2    Myanmar Win Gate Gems Jewellery Mining         0.0
# 3    Myanmar Win Gate Gems Jewellery Mining         0.0
# 4    Myanmar Win Gate Gems Jewellery Mining         0.0
# 5    Myanmar Win Gate Gems Jewellery Mining         0.0
# 6    Myanmar Win Gate Gems Jewellery Mining         0.0
# 7    Myanmar Win Gate Gems Jewellery Mining         0.0
# 8    Myanmar Win Gate Gems Jewellery Mining         0.0
# 9    Myanmar Win Gate Gems Jewellery Mining         0.0
# 10   Myanmar Win Gate Gems Jewellery Mining         0.0
# 11   Myanmar Win Gate Gems Jewellery Mining         0.0
# 12   Myanmar Win Gate Gems Jewellery Mining         0.0
# 13              Sein Lom Taung Tan Gems Ltd         0.0
# 14              Sein Lom Taung Tan Gems Ltd         0.0
# 15              Sein Lom Taung Tan Gems Ltd         0.0
# 16              Sein Lom Taung Tan Gems Ltd         0.0
# 17              Sein Lom Taung Tan Gems Ltd         0.0
# 18              Sein Lom Taung Tan Gems Ltd         0.0
# 19              Sein Lom Taung Tan Gems Ltd         0.0
# 20              Sein Lom Taung Tan Gems Ltd         0.0
# 21              Sein Lom Taung Tan Gems Ltd         0.0
# 22              Sein Lom Taung Tan Gems Ltd         0.0
# 23              Sein Lom Taung Tan Gems Ltd         0.0
# 24              Sein Lom Taung Tan Gems Ltd         0.0
# 25              Sein Lom Taung Tan Gems Ltd         0.0
# 26                Yar Za Htar Ne Gems CoLtd         0.0
# 27                Yar Za Htar Ne Gems CoLtd         0.0
# 28                Yar Za Htar Ne Gems CoLtd         0.0
# 29                Yar Za Htar Ne Gems CoLtd         0.0
# ..                                      ...         ...
# 920           Golden Wallet Jewellery CoLtd         0.0
# 921           Golden Wallet Jewellery CoLtd         0.0
# 922           Golden Wallet Jewellery CoLtd         0.0
# 923                  Tun Tauk Sa Gems CoLtd         0.0
# 924                  Tun Tauk Sa Gems CoLtd         0.0
# 925                  Tun Tauk Sa Gems CoLtd         0.0
# 926                  Tun Tauk Sa Gems CoLtd         0.0
# 927                  Tun Tauk Sa Gems CoLtd         0.0
# 928                  Tun Tauk Sa Gems CoLtd         0.0
# 929                  Tun Tauk Sa Gems CoLtd         0.0
# 930                  Tun Tauk Sa Gems CoLtd         0.0
# 931                  Tun Tauk Sa Gems CoLtd         0.0
# 932                  Tun Tauk Sa Gems CoLtd         0.0
# 933                  Tun Tauk Sa Gems CoLtd         0.0
# 934                  Tun Tauk Sa Gems CoLtd         0.0
# 935                  Tun Tauk Sa Gems CoLtd         0.0
# 0      Companies not in EITI Reconciliation         NaN
# 1      Companies not in EITI Reconciliation         NaN
# 2      Companies not in EITI Reconciliation         NaN
# 3      Companies not in EITI Reconciliation         NaN
# 4      Companies not in EITI Reconciliation         NaN
# 5      Companies not in EITI Reconciliation         NaN
# 6      Companies not in EITI Reconciliation         NaN
# 7      Companies not in EITI Reconciliation         NaN
# 8      Companies not in EITI Reconciliation         NaN
# 9      Companies not in EITI Reconciliation         NaN
# 10     Companies not in EITI Reconciliation         NaN
# 11     Companies not in EITI Reconciliation         NaN
# 2    entity    5.617191e+08
# 3    entity    0.000000e+00
# 4    entity    0.000000e+00
# 5    entity    0.000000e+00
# 6    entity    0.000000e+00
# 7    entity    5.616360e+08
# 8    entity    0.000000e+00
# 9    entity    0.000000e+00
# 10   entity    7.603074e+06
# 11   entity    0.000000e+00
# 12   entity    0.000000e+00
# 13   entity    1.173013e+10
# 14   entity    2.068655e+09
# 15   entity    3.736949e+08
# 16   entity    0.000000e+00
# 17   entity    1.110562e+08
# 18   entity    0.000000e+00
# 19   entity    0.000000e+00
# 20   entity    2.636963e+08
# 21   entity    0.000000e+00
# 22   entity    0.000000e+00
# 23   entity    0.000000e+00
# 24   entity    0.000000e+00
# 25   entity    0.000000e+00
# 26   entity    8.375401e+09
# 27   entity    1.487428e+09
# 28   entity    2.604500e+08
# 29   entity    0.000000e+00
# ..      ...             ...
# 920  entity    0.000000e+00
# 921  entity    0.000000e+00
# 922  entity    0.000000e+00
# 923  entity    0.000000e+00
# 924  entity    2.971649e+08
# 925  entity    3.820686e+07
# 926  entity    0.000000e+00
# 927  entity    1.795500e+05
# 928  entity    0.000000e+00
# 929  entity    1.080000e+06
# 930  entity    0.000000e+00
# 931  entity    0.000000e+00
# 932  entity    0.000000e+00
# 933  entity    0.000000e+00
# 934  entity    0.000000e+00
# 935  entity    0.000000e+00
# 0    entity    4.397494e+09
# 1    entity    7.636323e+09
# 2    entity    2.837937e+10
# 3    entity    1.216259e+10
# 4    entity    7.207333e+10
# 5    entity    1.850704e+08
# 6    entity    3.645330e+09
# 7    entity    5.360554e+09
# 8    entity    4.822221e+09
# 9    entity    4.569416e+09
# 10   entity    2.235075e+10
# 11   entity    2.091258e+09
# 12   entity    6.166018e+08
# 13   entity    2.860000e+06
#
# [950 rows x 7 columns]

# %%
df_gemsjade['name_of_revenue_stream'] = df_gemsjade['name_of_revenue_stream'].replace({'Other significant payments (&gt; 50,000 USD)': 'Other significant payments (> 50,000 USD)'})

# %%
company_totals = df_gemsjade.pivot_table(index=['Company_name_cl'], aggfunc='sum')['value_reported']
company_totals = company_totals.to_frame()
company_totals.rename(columns={'value_reported': 'total_payments'}, inplace=True)
company_totals.reset_index(level=0, inplace=True)
company_totals.sort_values(by=['total_payments'], ascending = False, inplace=True)
company_totals
# Out:
#                                       Company_name_cl  total_payments
# 5                Companies not in EITI Reconciliation    1.682932e+11
# 39             Myanmar Win Gate Gems Jewellery Mining    2.751600e+10
# 70                          Yar Za Htar Ne Gems CoLtd    1.574492e+10
# 53                        Sein Lom Taung Tan Gems Ltd    1.454723e+10
# 63                         Wai Aung Gabar Gems Co Ltd    8.578462e+09
# 2                                    Ayar Jade Co Ltd    8.444627e+09
# 36                Myanmar Imperial JadeGems Jewellery    7.930705e+09
# 65              Yadanar Kaung Kin Gems JewelleryCoLtd    7.703416e+09
# 40                              Myat Yamon Gems CoLtd    7.009035e+09
# 24                             Kyauk Seinn Nagar Gems    6.851944e+09
# 38                            Myanmar Sithu Jewellery    6.485012e+09
# 30                         Linn Lett Win Yadanar Gems    6.222289e+09
# 68                            Yadanar Taung Tann Gems    4.364834e+09
df_gemsjade = df_gemsjade[df_gemsjade["value_reported"] > 0]
df_gemsjade = df_gemsjade.sort_values(by=['total_payments'], ascending=False)
df_gemsjade
# Out:
#                             Company_name_cl  Unnamed: 0  \
# 949    Companies not in EITI Reconciliation         NaN
# 948    Companies not in EITI Reconciliation         NaN
# 947    Companies not in EITI Reconciliation         NaN
# 946    Companies not in EITI Reconciliation         NaN
# 945    Companies not in EITI Reconciliation         NaN
# 944    Companies not in EITI Reconciliation         NaN
# 943    Companies not in EITI Reconciliation         NaN
# 942    Companies not in EITI Reconciliation         NaN
# 941    Companies not in EITI Reconciliation         NaN
# 940    Companies not in EITI Reconciliation         NaN
# 939    Companies not in EITI Reconciliation         NaN
# 938    Companies not in EITI Reconciliation         NaN
# 937    Companies not in EITI Reconciliation         NaN
# 936    Companies not in EITI Reconciliation         NaN
# 1    Myanmar Win Gate Gems Jewellery Mining         0.0
# 0    Myanmar Win Gate Gems Jewellery Mining         0.0
# 7    Myanmar Win Gate Gems Jewellery Mining         0.0
# 2    Myanmar Win Gate Gems Jewellery Mining         0.0
# 10   Myanmar Win Gate Gems Jewellery Mining         0.0
# 26                Yar Za Htar Ne Gems CoLtd         0.0
# 27                Yar Za Htar Ne Gems CoLtd         0.0
# 28                Yar Za Htar Ne Gems CoLtd         0.0
# 30                Yar Za Htar Ne Gems CoLtd         0.0
# 32                Yar Za Htar Ne Gems CoLtd         0.0
# 37                Yar Za Htar Ne Gems CoLtd         0.0
# 33                Yar Za Htar Ne Gems CoLtd         0.0
# 35                Yar Za Htar Ne Gems CoLtd         0.0
# 38                Yar Za Htar Ne Gems CoLtd         0.0
# 20              Sein Lom Taung Tan Gems Ltd         0.0
# 17              Sein Lom Taung Tan Gems Ltd         0.0
# ..                                      ...         ...
# 674              Lin Yaung Phyar Gems CoLtd         0.0
# 651      Zwe Htet Lwin Gems Jewellery CoLtd         0.0
# 652      Zwe Htet Lwin Gems Jewellery CoLtd         0.0
# 924                  Tun Tauk Sa Gems CoLtd         0.0
# 929                  Tun Tauk Sa Gems CoLtd         0.0
# 927                  Tun Tauk Sa Gems CoLtd         0.0
# 925                  Tun Tauk Sa Gems CoLtd         0.0
# 612           Golden Grate Wall Gems Co Ltd         0.0
# 615           Golden Grate Wall Gems Co Ltd         0.0
# 613           Golden Grate Wall Gems Co Ltd         0.0
# 639  Phar Kant Yar Zar Gems Jewellery CoLtd         0.0
# 638  Phar Kant Yar Zar Gems Jewellery CoLtd         0.0
# 648  Phar Kant Yar Zar Gems Jewellery CoLtd         0.0
# 919           Golden Wallet Jewellery CoLtd         0.0
# 916           Golden Wallet Jewellery CoLtd         0.0
# 912           Golden Wallet Jewellery CoLtd         0.0
# 911           Golden Wallet Jewellery CoLtd         0.0
# 899                     Big Jade Gems CoLtd         0.0
# 898                     Big Jade Gems CoLtd         0.0
# 820                                Kyay Lin         0.0
# 821                                Kyay Lin         0.0
# 719                      NILAR YOMA TRADING         0.0
# 716                      NILAR YOMA TRADING         0.0
# 717                      NILAR YOMA TRADING         0.0
# 721                      NILAR YOMA TRADING         0.0
# 680        Production Royalties      Myanmar Gems Enterprise
# 685        Corporate Income Tax  Internal Revenue Department
# 373        Corporate Income Tax  Internal Revenue Department
#
#        type  value_reported  total_payments
# 949  entity    2.860000e+06    1.682932e+11
# 948  entity    6.166018e+08    1.682932e+11
# 947  entity    2.091258e+09    1.682932e+11
# 946  entity    2.235075e+10    1.682932e+11
# 945  entity    4.569416e+09    1.682932e+11
# 944  entity    4.822221e+09    1.682932e+11
# 943  entity    5.360554e+09    1.682932e+11
# 942  entity    3.645330e+09    1.682932e+11
# 941  entity    1.850704e+08    1.682932e+11
# 940  entity    7.207333e+10    1.682932e+11
# 939  entity    1.216259e+10    1.682932e+11
# 938  entity    2.837937e+10    1.682932e+11
# 937  entity    7.636323e+09    1.682932e+11
# 936  entity    4.397494e+09    1.682932e+11
# 1    entity    4.368923e+09    2.751600e+10
# 0    entity    2.201612e+10    2.751600e+10
# 7    entity    5.616360e+08    2.751600e+10
# 2    entity    5.617191e+08    2.751600e+10
# 10   entity    7.603074e+06    2.751600e+10
# 26   entity    8.375401e+09    1.574492e+10
# 27   entity    1.487428e+09    1.574492e+10
# 28   entity    2.604500e+08    1.574492e+10
# 30   entity    1.332788e+08    1.574492e+10
# 32   entity    2.000000e+06    1.574492e+10
# 37   entity    1.516832e+08    1.574492e+10
# 33   entity    1.912409e+08    1.574492e+10
# 35   entity    2.998485e+08    1.574492e+10
# 38   entity    4.843588e+09    1.574492e+10
# 20   entity    2.636963e+08    1.454723e+10
# 17   entity    1.110562e+08    1.454723e+10
# ..      ...             ...             ...
# 674  entity    5.435758e+07    4.180543e+08
# 651  entity    2.963133e+08    3.591544e+08
# 652  entity    6.284109e+07    3.591544e+08
# 924  entity    2.971649e+08    3.366313e+08
# 929  entity    1.080000e+06    3.366313e+08
# 927  entity    1.795500e+05    3.366313e+08
# 925  entity    3.820686e+07    3.366313e+08
# 612  entity    2.018626e+08    2.492989e+08
# 615  entity    1.733608e+07    2.492989e+08
# 613  entity    3.010022e+07    2.492989e+08
# 639  entity    8.423371e+07    2.103133e+08
# 638  entity    1.014251e+08    2.103133e+08
# 648  entity    2.465445e+07    2.103133e+08
# 919  entity    3.381440e+05    1.936095e+08
# 916  entity    2.328000e+07    1.936095e+08
# 912  entity    1.936611e+07    1.936095e+08
# 911  entity    1.506253e+08    1.936095e+08
# 899  entity    1.185500e+07    1.040620e+08
# 898  entity    9.220696e+07    1.040620e+08
# 820  entity    6.001654e+07    7.270754e+07
# 821  entity    1.269100e+07    7.270754e+07
# 719  entity    1.414700e+06    3.281485e+07
# 716  entity    2.390905e+07    3.281485e+07
# 717  entity    4.610978e+05    3.281485e+07
# 721  entity    7.030000e+06    3.281485e+07
# 677  entity    1.797777e+07    2.552203e+07
# 678  entity    2.462058e+06    2.552203e+07
# 680  entity    9.067200e+05    2.552203e+07
# 685  entity    4.175482e+06    2.552203e+07
# 373  entity    7.560000e+06    7.560000e+06
#
# [364 rows x 8 columns]

# %% [markdown]
# ## Prepare Source-Target-Value dataframe

# %%
links = pd.DataFrame(columns=['source','target','value','type'])

# %%
to_append = df_gemsjade.groupby(['name_of_revenue_stream','paid_to'],as_index=False)['type','value_reported','total_payments'].sum()

#to_append["target"] = "Myanmar Gems Enterprise"
to_append.rename(columns = {'name_of_revenue_stream':'source', 'value_reported' : 'value', 'paid_to': 'target'}, inplace = True)

to_append = to_append.sort_values(by=['value'], ascending = False)
to_append['target_type'] = 'entity'
links = pd.concat([links,to_append])

print(to_append['value'].sum())
links
# Out:
# 367956328249.0
#                         source                       target target_type  \
# 12                  Sale Split      Myanmar Gems Enterprise      entity
# 9                  Permit Fees      Myanmar Gems Enterprise      entity
# 14             Sales Royalties      Myanmar Gems Enterprise      entity
# 11                   Royalties  Internal Revenue Department      entity
# 1               Commercial Tax  Internal Revenue Department      entity
# 15                Service Fees      Myanmar Gems Enterprise      entity
# 3               Customs Duties           Customs Department      entity
# 4                Emporium Fees             Central Comittee      entity
# 10        Production Royalties      Myanmar Gems Enterprise      entity
# 5    Emporium Fees / Sale Fees      Myanmar Gems Enterprise      entity
# 13             Sales Royalties  Internal Revenue Department      entity
# 8   Other significant payments      Myanmar Gems Enterprise      entity
# 6               Incentive Fees      Myanmar Gems Enterprise      entity
# 2         Corporate Income Tax  Internal Revenue Department      entity
# 7                   Income Tax  Internal Revenue Department      entity
# 16             Withholding Tax  Internal Revenue Department      entity
# 0            Capital Gains Tax  Internal Revenue Department      entity
#
#     total_payments type         value
# 12    3.360148e+11  NaN  1.228661e+11
# 9     2.343554e+11  NaN  8.190276e+10
# 14    3.590730e+11  NaN  6.872314e+10
# 11    1.682932e+11  NaN  2.235075e+10
# 1     2.454533e+11  NaN  1.501441e+10
# 15    1.682932e+11  NaN  1.216259e+10
# 3     2.364244e+11  NaN  7.914103e+09
# 4     1.914022e+11  NaN  7.414528e+09
# 10    3.050301e+11  NaN  7.279748e+09
# 5     1.682932e+11  NaN  5.360554e+09
# 13    1.804274e+10  NaN  4.930483e+09
# 8     1.682932e+11  NaN  3.645330e+09
# 6     3.351364e+11  NaN  2.919597e+09
# 2     1.030625e+11  NaN  2.761518e+09
# 7     1.682932e+11  NaN  2.091258e+09
# 16    1.682932e+11  NaN  6.166018e+08
# 0     1.682932e+11  NaN  2.860000e+06

# %%
append_dict_transfers = [{'source': 'Myanmar Gems Enterprise', 'type': 'entity', 
                       'target': 'State Contribution', 'value': 46833942000 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity', 
                       'target': 'Commercial Tax', 'value': 15000000 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity',
                       'target': 'Corporate Income Tax', 'value': 53788313000 }]

"""
                         
                         {'source': 'State Contribution', 'target-type': 'entity','target-type': 'entity',
                       'target': 'Ministry of Finance', 'value': 46833942000 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity',
                       'target': 'Royalties on Production', 'value': 17249087176 },
                         
                         {'source': 'Corporate Income Tax',  'target-type': 'entity','target-type': 'entity',
                       'target': 'Internal Revenue Department', 'value': 53788313000 },
                         
                         {'source': 'Commercial Tax', 'target-type': 'entity',
                       'target': 'Internal Revenue Department', 'value': 15000000 }]

"""

append_dict_transfers_df = pd.DataFrame(append_dict_transfers)
#links = pd.concat([links, append_dict_transfers_df])

# %%
to_append = df_gemsjade.groupby(['name_of_revenue_stream','Company_name_cl','type'],as_index=False) \
    ['value_reported','total_payments'] \
    .agg({'value_reported':sum,'total_payments':'first'})
to_append.rename(columns = {'Company_name_cl':'source','name_of_revenue_stream':'target', 'value_reported' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=
# 298             Sales Royalties                     Big Jade Gems CoLtd
# 75                Emporium Fees                     Big Jade Gems CoLtd
# 320             Sales Royalties                                Kyay Lin
# 97                Emporium Fees                                Kyay Lin
# 333             Sales Royalties                      NILAR YOMA TRADING
# 110               Emporium Fees                      NILAR YOMA TRADING
# 200                 Permit Fees                      NILAR YOMA TRADING
# 235        Production Royalties                      NILAR YOMA TRADING
# 89                Emporium Fees                Kaung Wai Yan Gems CoLtd
# 312             Sales Royalties                Kaung Wai Yan Gems CoLtd
# 27         Corporate Income Tax                Kaung Wai Yan Gems CoLtd
# 222        Production Royalties                Kaung Wai Yan Gems CoLtd
# 44         Corporate Income Tax   Thit Sar Pan U Kyaw Min Naing private
#
#        type         value  total_payments
# 0    entity  2.860000e+06    1.682932e+11
# 53   entity  4.822221e+09    1.682932e+11
# 360  entity  1.216259e+10    1.682932e+11
# 300  entity  2.837937e+10    1.682932e+11
# 257  entity  7.636323e+09    1.682932e+11
# 253  entity  2.235075e+10    1.682932e+11
# 214  entity  4.397494e+09    1.682932e+11
# 182  entity  7.207333e+10    1.682932e+11
# 179  entity  3.645330e+09    1.682932e+11
# 178  entity  2.091258e+09    1.682932e+11
# 141  entity  1.850704e+08    1.682932e+11
# 137  entity  5.360554e+09    1.682932e+11
# 361  entity  6.166018e+08    1.682932e+11
# 3    entity  4.569416e+09    1.682932e+11
# 107  entity  5.617191e+08    2.751600e+10
# 157  entity  5.616360e+08    2.751600e+10
# 274  entity  2.201612e+10    2.751600e+10
# 11   entity  7.603074e+06    2.751600e+10
# 330  entity  4.368923e+09    2.751600e+10
# 252  entity  1.332788e+08    1.574492e+10
# 358  entity  6.331016e+09    1.574492e+10
# 135  entity  2.604500e+08    1.574492e+10
# 51   entity  2.998485e+08    1.574492e+10
# 71   entity  1.516832e+08    1.574492e+10
# 177  entity  1.912409e+08    1.574492e+10
# 209  entity  2.000000e+06    1.574492e+10
# 294  entity  8.375401e+09    1.574492e+10
# 344  entity  2.068655e+09    1.454723e+10
# 168  entity  2.636963e+08    1.454723e+10
# 242  entity  1.110562e+08    1.454723e+10
# ..      ...           ...             ...
# 98   entity  9.555200e+07    4.180543e+08
# 359  entity  2.963133e+08    3.591544e+08
# 136  entity  6.284109e+07    3.591544e+08
# 247  entity  1.795500e+05    3.366313e+08
# 128  entity  3.820686e+07    3.366313e+08
# 351  entity  2.971649e+08    3.366313e+08
# 206  entity  1.080000e+06    3.366313e+08
# 303  entity  2.018626e+08    2.492989e+08
# 216  entity  1.733608e+07    2.492989e+08
# 79   entity  3.010022e+07    2.492989e+08
# 64   entity  2.465445e+07    2.103133e+08
# 115  entity  8.423371e+07    2.103133e+08
# 338  entity  1.014251e+08    2.103133e+08
# 185  entity  2.328000e+07    1.936095e+08
# 304  entity  1.506253e+08    1.936095e+08
# 22   entity  3.381440e+05    1.936095e+08
# 80   entity  1.936611e+07    1.936095e+08
# 298  entity  9.220696e+07    1.040620e+08
# 75   entity  1.185500e+07    1.040620e+08
# 320  entity  6.001654e+07    7.270754e+07
# 97   entity  1.269100e+07    7.270754e+07
# 333  entity  2.390905e+07    3.281485e+07
# 110  entity  4.610978e+05    3.281485e+07
# 200  entity  7.030000e+06    3.281485e+07
# 235  entity  1.414700e+06    3.281485e+07
# 89   entity  2.462058e+06    2.552203e+07
# 312  entity  1.797777e+07    2.552203e+07
# 27   entity  4.175482e+06    2.552203e+07
# 222  entity  9.067200e+05    2.552203e+07
# 44   entity  7.560000e+06    7.560000e+06
#
# [362 rows x 5 columns]

# %%
#to_append = df.groupby(['name_of_revenue_stream','Company_name_cl'],as_index=False)['Value (USD)'].sum()
#to_append.rename(columns = {'Payment Type':'source','Reporting Company':'target', 'Value (USD)' : 'value'}, inplace = True)
#to_append = to_append.sort_values(by=['value'], ascending = False)
#links = pd.concat([links,to_append])

#print(to_append['value'].sum())
#links

# %%
unique_source = links['source'].unique()
unique_targets = links['target'].unique()

unique_source = pd.merge(pd.DataFrame(unique_source), links, left_on=0, right_on='source', how='left')
unique_source = unique_source.filter([0,'type'])
unique_targets = pd.merge(pd.DataFrame(unique_targets), links, left_on=0, right_on='target', how='left')
unique_targets = unique_targets.filter([0,'target_type'])
unique_targets.rename(columns = {'target_type':'type'}, inplace = True)

unique_list = pd.concat([unique_source[0], unique_targets[0]]).unique()

unique_list = pd.merge(pd.DataFrame(unique_list), \
                       pd.concat([unique_source, unique_targets]), left_on=0, right_on=0, how='left')

unique_list.drop_duplicates(subset=0, keep='first', inplace=True)

replace_dict = {k: v for v, k in enumerate(unique_list[0])}
unique_list


#unique_list = pd.concat([links['source'], links['target']]).unique()
#replace_dict = {k: v for v, k in enumerate(unique_list)}
# Out:
#                                                      0    type
# 0                                           Sale Split     NaN
# 42                                         Permit Fees     NaN
# 73                                     Sales Royalties     NaN
# 140                                          Royalties     NaN
# 142                                     Commercial Tax     NaN
# 159                                       Service Fees     NaN
# 161                                     Customs Duties     NaN
# 182                                      Emporium Fees     NaN
# 248                               Production Royalties     NaN
# 292                          Emporium Fees / Sale Fees     NaN
# 294                         Other significant payments     NaN
# 296                                     Incentive Fees     NaN
# 337                               Corporate Income Tax     NaN
# 373                                         Income Tax     NaN
# 375                                    Withholding Tax     NaN
# 377                                  Capital Gains Tax     NaN
# 379               Companies not in EITI Reconciliation  entity
# 393             Myanmar Win Gate Gems Jewellery Mining  entity
# 398                          Yar Za Htar Ne Gems CoLtd  entity
# 406                        Sein Lom Taung Tan Gems Ltd  entity
# 411                         Wai Aung Gabar Gems Co Ltd  entity
# 419                                   Ayar Jade Co Ltd  entity
# 425                Myanmar Imperial JadeGems Jewellery  entity
# 428              Yadanar Kaung Kin Gems JewelleryCoLtd  entity
# 431                              Myat Yamon Gems CoLtd  entity
# 439                             Kyauk Seinn Nagar Gems  entity
# 444                            Myanmar Sithu Jewellery  entity
# 452                         Linn Lett Win Yadanar Gems  entity
# 461                            Yadanar Taung Tann Gems  entity
# 467              Khin Zaw Aung Brothers Gems Jewellery  entity
# ..                                                 ...     ...
# 647                              Pang Huke Duwa Co Ltd  entity
# 652                      Ngwe Hein Htet Gems Jewellery  entity
# 658                         Oo Ya Gems Jewellery CoLtd  entity
# 663           Jade Padathar Gems Shwe Gaung Gaung Gems  entity
# 668                           Aung Hein Min Gems CoLtd  entity
# 675  Than Lwin Aye Yar Gems Co Ltd Kaung Myat Thu K...  entity
# 680               EIGHTY THOUSAND GEMS JEWELLERY CoLtd  entity
# 684                      Yadanar San Shwin Gems Co Ltd  entity
# 688                             Mann Ayer Family CoLtd  entity
# 690               Kyauk Gyi Gone Gems Jewellery Co Ltd  entity
# 695                    Kan Par Ni Gems Jewellery CoLtd  entity
# 698                      Myanmar Economics Corporation  entity
# 701                                 KHA YANN MYAY GEMS  entity
# 704                         YadanarYaungChi Gems CoLtd  entity
# 708                                     Kyaw Thet Aung  entity
# 709                         Lin Yaung Phyar Gems CoLtd  entity
# 712                 Zwe Htet Lwin Gems Jewellery CoLtd  entity
# 714                             Tun Tauk Sa Gems CoLtd  entity
# 718                      Golden Grate Wall Gems Co Ltd  entity
# 721             Phar Kant Yar Zar Gems Jewellery CoLtd  entity
# 724                      Golden Wallet Jewellery CoLtd  entity
# 728                                Big Jade Gems CoLtd  entity
# 730                                           Kyay Lin  entity
# 732                                 NILAR YOMA TRADING  entity
# 736                           Kaung Wai Yan Gems CoLtd  entity
# 740              Thit Sar Pan U Kyaw Min Naing private  entity
# 741                            Myanmar Gems Enterprise  entity
# 749                        Internal Revenue Department  entity
# 756                                 Customs Department  entity
# 757                                   Central Comittee  entity
#
# [89 rows x 2 columns]

# %%
links_replaced = links.replace({"source": replace_dict,"target": replace_dict})

# %%
links_replaced
# Out:
#      source  target target_type  total_payments    type         value
# 12        0      85      entity    3.360148e+11     NaN  1.228661e+11
# 9         1      85      entity    2.343554e+11     NaN  8.190276e+10
# 14        2      85      entity    3.590730e+11     NaN  6.872314e+10
# 11        3      86      entity    1.682932e+11     NaN  2.235075e+10
# 1         4      86      entity    2.454533e+11     NaN  1.501441e+10
# 15        5      85      entity    1.682932e+11     NaN  1.216259e+10
# 3         6      87      entity    2.364244e+11     NaN  7.914103e+09
# 4         7      88      entity    1.914022e+11     NaN  7.414528e+09
# 10        8      85      entity    3.050301e+11     NaN  7.279748e+09
# 5         9      85      entity    1.682932e+11     NaN  5.360554e+09
# 13        2      86      entity    1.804274e+10     NaN  4.930483e+09
# 8        10      85      entity    1.682932e+11     NaN  3.645330e+09
# 6        11      85      entity    3.351364e+11     NaN  2.919597e+09
# 2        12      86      entity    1.030625e+11     NaN  2.761518e+09
# 7        13      86      entity    1.682932e+11     NaN  2.091258e+09
# 16       14      86      entity    1.682932e+11     NaN  6.166018e+08
# 0        15      86      entity    1.682932e+11     NaN  2.860000e+06
# 0        16      15         NaN    1.682932e+11  entity  2.860000e+06
# 53       16       6         NaN    1.682932e+11  entity  4.822221e+09
# 360      16       5         NaN    1.682932e+11  entity  1.216259e+10
# 300      16       2         NaN    1.682932e+11  entity  2.837937e+10
# 257      16       0         NaN    1.682932e+11  entity  7.636323e+09
# 253      16       3         NaN    1.682932e+11  entity  2.235075e+10
# 214      16       8         NaN    1.682932e+11  entity  4.397494e+09
# 182      16       1         NaN    1.682932e+11  entity  7.207333e+10
# 179      16      10         NaN    1.682932e+11  entity  3.645330e+09
# 178      16      13         NaN    1.682932e+11  entity  2.091258e+09
# 141      16      11         NaN    1.682932e+11  entity  1.850704e+08
# 137      16       9         NaN    1.682932e+11  entity  5.360554e+09
# 361      16      14         NaN    1.682932e+11  entity  6.166018e+08
# ..      ...     ...         ...             ...     ...           ...
# 98       74       7         NaN    4.180543e+08  entity  9.555200e+07
# 359      75       2         NaN    3.591544e+08  entity  2.963133e+08
# 136      75       7         NaN    3.591544e+08  entity  6.284109e+07
# 247      76       8         NaN    3.366313e+08  entity  1.795500e+05
# 128      76       7         NaN    3.366313e+08  entity  3.820686e+07
# 351      76       2         NaN    3.366313e+08  entity  2.971649e+08
# 206      76       1         NaN    3.366313e+08  entity  1.080000e+06
# 303      77       2         NaN    2.492989e+08  entity  2.018626e+08
# 216      77       8         NaN    2.492989e+08  entity  1.733608e+07
# 79       77       7         NaN    2.492989e+08  entity  3.010022e+07
# 64       78       6         NaN    2.103133e+08  entity  2.465445e+07
# 115      78       7         NaN    2.103133e+08  entity  8.423371e+07
# 338      78       2         NaN    2.103133e+08  entity  1.014251e+08
# 185      79       1         NaN    1.936095e+08  entity  2.328000e+07
# 304      79       2         NaN    1.936095e+08  entity  1.506253e+08
# 22       79      12         NaN    1.936095e+08  entity  3.381440e+05
# 80       79       7         NaN    1.936095e+08  entity  1.936611e+07
# 298      80       2         NaN    1.040620e+08  entity  9.220696e+07
# 75       80       7         NaN    1.040620e+08  entity  1.185500e+07
# 320      81       2         NaN    7.270754e+07  entity  6.001654e+07
# 97       81       7         NaN    7.270754e+07  entity  1.269100e+07
# 333      82       2         NaN    3.281485e+07  entity  2.390905e+07
# 110      82       7         NaN    3.281485e+07  entity  4.610978e+05
# 200      82       1         NaN    3.281485e+07  entity  7.030000e+06
# 235      82       8         NaN    3.281485e+07  entity  1.414700e+06
# 89       83       7         NaN    2.552203e+07  entity  2.462058e+06
# 312      83       2         NaN    2.552203e+07  entity  1.797777e+07
# 27       83      12         NaN    2.552203e+07  entity  4.175482e+06
# 222      83       8         NaN    2.552203e+07  entity  9.067200e+05
# 44       84      12         NaN    7.560000e+06  entity  7.560000e+06
#
# [379 rows x 6 columns]

# %%
nodes = pd.DataFrame(unique_list)
nodes.rename(columns = {0:'name'}, inplace = True)

# %%
nodes_json= pd.DataFrame(nodes).to_json(orient='records')
nodes_json
# Out:
# '[{"name":"Sale Split","type":null},{"name":"Permit Fees","type":null},{"name":"Sales Royalties","type":null},{"name":"Royalties","type":null},{"name":"Commercial Tax","type":null},{"name":"Service Fees","type":null},{"name":"Customs Duties","type":null},{"name":"Emporium Fees","type":null},{"name":"Production Royalties","type":null},{"name":"Emporium Fees \\/ Sale Fees","type":null},{"name":"Other significant payments","type":null},{"name":"Incentive Fees","type":null},{"name":"Corporate Income Tax","type":null},{"name":"Income Tax","type":null},{"name":"Withholding Tax","type":null},{"name":"Capital Gains Tax","type":null},{"name":"Companies not in EITI Reconciliation","type":"entity"},{"name":"Myanmar Win Gate Gems Jewellery Mining","type":"entity"},{"name":"Yar Za Htar Ne Gems CoLtd","type":"entity"},{"name":"Sein Lom Taung Tan Gems Ltd","type":"entity"},{"name":"Wai Aung Gabar Gems Co Ltd","type":"entity"},{"name":"Ayar Jade Co Ltd","type":"entity"},{"name":"Myanmar Imperial JadeGems Jewellery","type":"entity"},{"name":"Yadanar Kaung Kin Gems JewelleryCoLtd","type":"entity"},{"name":"Myat Yamon Gems CoLtd","type":"entity"},{"name":"Kyauk Seinn Nagar Gems","type":"entity"},{"name":"Myanmar Sithu Jewellery","type":"entity"},{"name":"Linn Lett Win Yadanar Gems","type":"entity"},{"name":"Yadanar Taung Tann Gems","type":"entity"},{"name":"Khin Zaw Aung Brothers Gems Jewellery","type":"entity"},{"name":"Shwe Gaung Gaung Gems","type":"entity"},{"name":"Xie Family","type":"entity"},{"name":"Great Genesis Gems Co Ltd","type":"entity"},{"name":"RUBY DRAGON JADE GEMS CoLtd","type":"entity"},{"name":"Richest Gems CoLtd","type":"entity"},{"name":"Khine Myanmar Gems CoLtd","type":"entity"},{"name":"Myanma Seinn Lei Aung Gems","type":"entity"},{"name":"Khun PaOh Gems Jewellery","type":"entity"},{"name":"Kyaing International Gems","type":"entity"},{"name":"Jade Mountain Gems CoLtd","type":"entity"},{"name":"Phyo Thiha Kyaw Gems","type":"entity"},{"name":"Myo Nwe Gems Jewellery","type":"entity"},{"name":"SHWE BYAIN PHYU CO","type":"entity"},{"name":"Silver Elephant Gems","type":"entity"},{"name":"Shining Star Light Gems Jewellery","type":"entity"},{"name":"Chaow Brothers Gemstone","type":"entity"},{"name":"Kyaw Naing Brothers","type":"entity"},{"name":"Tun Naing Aung Gems","type":"entity"},{"name":"Thi Raw Mani Gems Jewellery","type":"entity"},{"name":"Myanmar Naing Group","type":"entity"},{"name":"Pho Thar Htoo Gems Co Ltd","type":"entity"},{"name":"111 Gems Jewellery","type":"entity"},{"name":"Lyan Shan Jewellery Co Ltd","type":"entity"},{"name":"Yadanar Pyi Phyo Aung Gems And Jewellery Co Ltd","type":"entity"},{"name":"PAING PHYO THIHA GEMS","type":"entity"},{"name":"Kachin National Development","type":"entity"},{"name":"Ever Winner Gems","type":"entity"},{"name":"HTOO JEWELLERY COLTD","type":"entity"},{"name":"Kan Pwint Oo","type":"entity"},{"name":"Pang Huke Duwa Co Ltd","type":"entity"},{"name":"Ngwe Hein Htet Gems Jewellery","type":"entity"},{"name":"Oo Ya Gems Jewellery CoLtd","type":"entity"},{"name":"Jade Padathar Gems Shwe Gaung Gaung Gems","type":"entity"},{"name":"Aung Hein Min Gems CoLtd","type":"entity"},{"name":"Than Lwin Aye Yar Gems Co Ltd Kaung Myat Thu Kha Co Ltd","type":"entity"},{"name":"EIGHTY THOUSAND GEMS JEWELLERY CoLtd","type":"entity"},{"name":"Yadanar San Shwin Gems Co Ltd","type":"entity"},{"name":"Mann Ayer Family CoLtd","type":"entity"},{"name":"Kyauk Gyi Gone Gems Jewellery Co Ltd","type":"entity"},{"name":"Kan Par Ni Gems Jewellery CoLtd","type":"entity"},{"name":"Myanmar Economics Corporation","type":"entity"},{"name":"KHA YANN MYAY GEMS","type":"entity"},{"name":"YadanarYaungChi Gems CoLtd","type":"entity"},{"name":"Kyaw Thet Aung","type":"entity"},{"name":"Lin Yaung Phyar Gems CoLtd","type":"entity"},{"name":"Zwe Htet Lwin Gems Jewellery CoLtd","type":"entity"},{"name":"Tun Tauk Sa Gems CoLtd","type":"entity"},{"name":"Golden Grate Wall Gems Co Ltd","type":"entity"},{"name":"Phar Kant Yar Zar Gems Jewe ...

# %%
links_json= pd.DataFrame(links_replaced).to_json(orient='records')
links_json
# Out:
# '[{"source":0,"target":85,"target_type":"entity","total_payments":336014767435.6849365234,"type":null,"value":122866104543.4000091553},{"source":1,"target":85,"target_type":"entity","total_payments":234355447525.369934082,"type":null,"value":81902763715.0},{"source":2,"target":85,"target_type":"entity","total_payments":359073022143.2430419922,"type":null,"value":68723135933.6229858398},{"source":3,"target":86,"target_type":"entity","total_payments":168293166958.0,"type":null,"value":22350747468.0},{"source":4,"target":86,"target_type":"entity","total_payments":245453313895.7850036621,"type":null,"value":15014407357.0499992371},{"source":5,"target":85,"target_type":"entity","total_payments":168293166958.0,"type":null,"value":12162588706.0},{"source":6,"target":87,"target_type":"entity","total_payments":236424394217.0799560547,"type":null,"value":7914102900.0},{"source":7,"target":88,"target_type":"entity","total_payments":191402185424.2429504395,"type":null,"value":7414527638.7100000381},{"source":8,"target":85,"target_type":"entity","total_payments":305030057185.5150756836,"type":null,"value":7279748325.0},{"source":9,"target":85,"target_type":"entity","total_payments":168293166958.0,"type":null,"value":5360554108.0},{"source":2,"target":86,"target_type":"entity","total_payments":18042741735.1299972534,"type":null,"value":4930483286.3000001907},{"source":10,"target":85,"target_type":"entity","total_payments":168293166958.0,"type":null,"value":3645329861.0},{"source":11,"target":85,"target_type":"entity","total_payments":335136435252.4349365234,"type":null,"value":2919596887.1599993706},{"source":12,"target":86,"target_type":"entity","total_payments":103062536508.365020752,"type":null,"value":2761517586.0},{"source":13,"target":86,"target_type":"entity","total_payments":168293166958.0,"type":null,"value":2091258147.0},{"source":14,"target":86,"target_type":"entity","total_payments":168293166958.0,"type":null,"value":616601787.0},{"source":15,"target":86,"target_type":"entity","total_payments":168293166958.0,"type":null,"value":2860000.0},{"source":16,"target":15,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":2860000.0},{"source":16,"target":6,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":4822220928.0},{"source":16,"target":5,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":12162588706.0},{"source":16,"target":2,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":28379373647.0},{"source":16,"target":0,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":7636322539.0},{"source":16,"target":3,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":22350747468.0},{"source":16,"target":8,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":4397493510.0},{"source":16,"target":1,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":72073329715.0},{"source":16,"target":10,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":3645329861.0},{"source":16,"target":13,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":2091258147.0},{"source":16,"target":11,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":185070361.0},{"source":16,"target":9,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":5360554108.0},{"source":16,"target":14,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":616601787.0},{"source":16,"target":4,"target_type":null,"total_payments":168293166958.0,"type":"entity","value":4569416181.0},{"source":17,"target":7,"target_type":null,"total_payments":27515999942.8200035095,"type":"entity","value":561719142.2699999809},{"source":17,"target":11,"target_type":null,"total_payments":27515999942.8200035095,"type":"entity","value":561635993.4900000095},{"source":17,"target":0,"target_type":null,"total_payments":27515999942.8200035095 ...

# %%
data = { 'links' : json.loads(links_json), 'nodes' : json.loads(nodes_json) }
data_json = json.dumps(data)
data_json = data_json.replace("\\","")
#print(data_json)
#with open('sankey_data.json', 'w') as outfile:
#    json.dump(data_json, outfile)

text_file = open("sankey_data_2014-15.json", "w")
text_file.write(data_json)
text_file.close()
