# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_csv('data/2015-16_gems_jade.csv')

# %%
# df = df[df['country'] == "Myanmar"]

# %%
df.head()
# Out:
#    Unnamed: 0               company_name      name_of_revenue_stream  \
# 0           0  Great Genesis Gems Co Ltd                  Sale Split
# 1           0  Great Genesis Gems Co Ltd             Sales Royalties
# 2           0  Great Genesis Gems Co Ltd               Emporium Fees
# 3           0  Great Genesis Gems Co Ltd  Other significant payments
# 4           0  Great Genesis Gems Co Ltd        Production Royalties
#
#                    paid_to  value_reported
# 0  Myanmar Gems Enterprise    6.350712e+09
# 1  Myanmar Gems Enterprise    1.984740e+09
# 2         Central Comittee    2.707704e+08
# 3  Myanmar Gems Enterprise    0.000000e+00
# 4  Myanmar Gems Enterprise    8.196838e+07

# %% [markdown]
# ## Clean data

# %%
df_gemsjade = df

df_gemsjade.rename(columns={'company_name': 'Company_name_cl'}, inplace=True)

df_gemsjade['type'] = 'entity'
df_gemsjade['target_type'] = ''

# %%
df_gemsjade.head()
# Out:
#    Unnamed: 0            Company_name_cl      name_of_revenue_stream  \
# 0           0  Great Genesis Gems Co Ltd                  Sale Split
# 1           0  Great Genesis Gems Co Ltd             Sales Royalties
# 2           0  Great Genesis Gems Co Ltd               Emporium Fees
# 3           0  Great Genesis Gems Co Ltd  Other significant payments
# 4           0  Great Genesis Gems Co Ltd        Production Royalties
#
#                    paid_to  value_reported    type target_type
# 0  Myanmar Gems Enterprise    6.350712e+09  entity
# 1  Myanmar Gems Enterprise    1.984740e+09  entity
# 2         Central Comittee    2.707704e+08  entity
# 3  Myanmar Gems Enterprise    0.000000e+00  entity
# 4  Myanmar Gems Enterprise    8.196838e+07  entity

# %%
append_dict_others = [{'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity', 
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Production Royalties', 'value_reported': 7627853015 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Sale Split', 'value_reported': 122565309 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Sales Royalties', 'value_reported': 1593381858 },

                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Service Fees', 'value_reported': 682734625 },
                     
                      {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Permit Fees', 'value_reported': 89494475808 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Incentive Fees', 'value_reported': 213344561 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Other significant payments', 'value_reported': 2637093845 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Emporium Fees / Sale Fees', 'value_reported': 2987472820 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Sale Split', 'value_reported': 5272471367 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Myanmar Gems Enterprise',
                       'name_of_revenue_stream': 'Commercial Tax', 'value_reported': 41353324562 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Customs Department',
                       'name_of_revenue_stream': 'Customs Duties', 'value_reported': 2985923707 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Commercial Tax', 'value_reported':  244080055733 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Royalties', 'value_reported':  76123095911 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Income Tax', 'value_reported':  4377920086 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Withholding Tax', 'value_reported':  51281036 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity',
                       'paid_to': 'Internal Revenue Department',
                       'name_of_revenue_stream': 'Capital Gains Tax', 'value_reported': 33708244 }
                     ]

others_df = pd.DataFrame(append_dict_others)
#others_df['total_payments'] = others_df['value_reported']
df_gemsjade = pd.concat([df_gemsjade, others_df])
df_gemsjade
# Out:
#                           Company_name_cl  Unnamed: 0  \
# 0               Great Genesis Gems Co Ltd         0.0
# 1               Great Genesis Gems Co Ltd         0.0
# 2               Great Genesis Gems Co Ltd         0.0
# 3               Great Genesis Gems Co Ltd         0.0
# 4               Great Genesis Gems Co Ltd         0.0
# 5               Great Genesis Gems Co Ltd         0.0
# 6               Great Genesis Gems Co Ltd         0.0
# 7               Great Genesis Gems Co Ltd         0.0
# 8               Great Genesis Gems Co Ltd         0.0
# 9               Great Genesis Gems Co Ltd         0.0
# 10              Great Genesis Gems Co Ltd         0.0
# 11              Great Genesis Gems Co Ltd         0.0
# 12              Great Genesis Gems Co Ltd         0.0
# 13            Sein Lom Taung Tan Gems Ltd         0.0
# 14            Sein Lom Taung Tan Gems Ltd         0.0
# 15            Sein Lom Taung Tan Gems Ltd         0.0
# 16            Sein Lom Taung Tan Gems Ltd         0.0
# 17            Sein Lom Taung Tan Gems Ltd         0.0
# 18            Sein Lom Taung Tan Gems Ltd         0.0
# 19            Sein Lom Taung Tan Gems Ltd         0.0
# 20            Sein Lom Taung Tan Gems Ltd         0.0
# 21            Sein Lom Taung Tan Gems Ltd         0.0
# 22            Sein Lom Taung Tan Gems Ltd         0.0
# 23            Sein Lom Taung Tan Gems Ltd         0.0
# 24            Sein Lom Taung Tan Gems Ltd         0.0
# 25            Sein Lom Taung Tan Gems Ltd         0.0
# 26             Wai Aung Gabar Gems Co Ltd         0.0
# 27             Wai Aung Gabar Gems Co Ltd         0.0
# 28             Wai Aung Gabar Gems Co Ltd         0.0
# 29             Wai Aung Gabar Gems Co Ltd         0.0
# ..                                    ...         ...
# 649            Green Light Treasure CoLtd         0.0
# 650                      Xie Family CoLtd         0.0
# 651                      Xie Family CoLtd         0.0
# 652                      Xie Family CoLtd         0.0
# 653                      Xie Family CoLtd         0.0
# 654                      Xie Family CoLtd         0.0
# 655                      Xie Family CoLtd         0.0
# 656                      Xie Family CoLtd         0.0
# 657                      Xie Family CoLtd         0.0
# 658                      Xie Family CoLtd         0.0
# 659                      Xie Family CoLtd         0.0
# 660                      Xie Family CoLtd         0.0
# 661                      Xie Family CoLtd         0.0
# 662                      Xie Family CoLtd         0.0
# 0    Companies not in EITI Reconciliation         NaN
# 1    Companies not in EITI Reconciliation         NaN
# 2    Companies not in EITI Reconciliation         NaN
# 3    Companies not in EITI Reconciliation         NaN
# 4    Companies not in EITI Reconciliation         NaN
# 5    Companies not in EITI Reconciliation         NaN
# 6    Companies not in EITI Reconciliation         NaN
# 7    Companies not in EITI Reconciliation         NaN
# 8    Companies not in EITI Reconciliation         NaN
# 9    Companies not in EITI Reconciliation         NaN
# 10   Companies not in EITI Reconciliation         NaN
# 11   Companies not in EITI Reconciliation         NaN
# 12   Companies not in EITI Reconciliation         NaN
# 13   Companies not in EITI Reconciliation         NaN
# 14   Companies not in EITI Reconciliation         NaN
# 15   Companies not in EITI Reconciliation         NaN
#
#          name_of_revenue_stream                      paid_to target_type  \
# 0                    Sale Split      Myanmar Gems Enterprise
# 1               Sales Royalties      Myanmar Gems Enterprise
# 2                 Emporium Fees             Central Comittee
# 3    Other significant payments      Myanmar Gems Enterprise
# 4          Production Royalties      Myanmar Gems Enterprise
# 5          Production Royalties          Department of Mines
# 6                   Permit Fees      Myanmar Gems Enterprise
# 7                Incentive Fees      Myanmar Gems Enterprise
# 8                Commercial Tax      Myanmar Gems Enterprise
# 9          Corporate Income Tax  Internal Revenue Department
# 10               Commercial Tax  Internal Revenue Department
# 11               Customs Duties           Customs Department
# 25   entity    0.000000e+00
# 26   entity    5.032759e+09
# 27   entity    1.167804e+09
# 28   entity    2.323034e+08
# 29   entity    0.000000e+00
# ..      ...             ...
# 649  entity    0.000000e+00
# 650  entity    1.097975e+08
# 651  entity    1.731675e+07
# 652  entity    3.141266e+06
# 653  entity    0.000000e+00
# 654  entity    0.000000e+00
# 655  entity    0.000000e+00
# 656  entity    0.000000e+00
# 657  entity    2.226478e+06
# 658  entity    7.039204e+07
# 659  entity    3.162464e+06
# 660  entity    0.000000e+00
# 661  entity    6.344284e+06
# 662  entity    0.000000e+00
# 0    entity    7.627853e+09
# 1    entity    1.225653e+08
# 2    entity    1.593382e+09
# 3    entity    6.827346e+08
# 4    entity    8.949448e+10
# 5    entity    2.133446e+08
# 6    entity    2.637094e+09
# 7    entity    2.987473e+09
# 8    entity    5.272471e+09
# 9    entity    4.135332e+10
# 10   entity    2.985924e+09
# 11   entity    2.440801e+11
# 12   entity    7.612310e+10
# 13   entity    4.377920e+09
# 14   entity    5.128104e+07
# 15   entity    3.370824e+07
#
# [679 rows x 7 columns]

# %%
df_gemsjade['name_of_revenue_stream'] = df_gemsjade['name_of_revenue_stream'].replace({'Other significant payments (&gt; 50,000 USD)': 'Other significant payments (> 50,000 USD)'})

# %%
company_totals = df_gemsjade.pivot_table(index=['Company_name_cl'], aggfunc='sum')['value_reported']
company_totals = company_totals.to_frame()
company_totals.rename(columns={'value_reported': 'total_payments'}, inplace=True)
company_totals.reset_index(level=0, inplace=True)
company_totals.sort_values(by=['total_payments'], ascending = False, inplace=True)
company_totals
# Out:
#                            Company_name_cl  total_payments
# 3     Companies not in EITI Reconciliation    4.796367e+11
# 6                Great Genesis Gems Co Ltd    1.366438e+10
# 37             Sein Lom Taung Tan Gems Ltd    1.344508e+10
# 45              Wai Aung Gabar Gems Co Ltd    1.165627e+10
# 0                         Ayar Jade Co Ltd    1.068263e+10
# 51               Yar Za Htar Ne Gems CoLtd    1.017084e+10
# 40      Shwe Pyi Tha Gems Trading Faceting    9.364859e+09
# 19              Linn Lett Win Yadanar Gems    9.147813e+09
# 24     Myanmar Imperial JadeGems Jewellery    8.524927e+09
# 16               Kyaing International Gems    8.075221e+09
# 33                      Richest Gems CoLtd    7.539189e+09
# 50            Yadanar Yaung Chi Gems CoLtd    7.430040e+09
# 49                 Yadanar Taung Tann Gems    7.267626e+09
# 27                   Myat Yamon Gems CoLtd    7.195363e+09
# 14   Khin Zaw Aung Brothers Gems Jewellery    6.963777e+09
# 47   Yadanar Kaung Kin Gems JewelleryCoLtd    5.608964e+09
# 9                 Jade Mountain Gems CoLtd    5.540052e+09
# 10             Kachin National Development    5.124867e+09
# 38       Shining Star Light Gems Jewellery    4.920827e+09
# 28                  Myo Nwe Gems Jewellery    4.730702e+09
# 15                Khun PaOh Gems Jewellery    4.665182e+09
# 1                             Ayar Yadanar    4.452844e+09
# 32                    Phyo Thiha Kyaw Gems    4.226541e+09
# 41                    Silver Elephant Gems    3.945428e+09
# 23              Myanma Seinn Lei Aung Gems    3.810868e+09
# 20                              Lucky Star    3.132891e+09
# 7                         Green Comet Gems    3.097177e+09
# 31                   Pang Huke Duwa Co Ltd    3.012267e+09
# 25                 Myanmar Sithu Jewellery    2.786658e+09
# 35                      SHWE BYAIN PHYU CO    2.539909e+09
# 42             Thi Raw Mani Gems Jewellery    2.395381e+09
# 34             SEIN THURA SAN GEMS COMPANY    2.373709e+09
# 30                Nay La Pwint Gems Co Ltd    2.144112e+09
# 12                       Kaung Myat Thukha    2.104477e+09
# 36              San Taw Win Gems Jewellery    1.928840e+09
# 39                   Shwe Gaung Gaung Gems    1.587433e+09
# 13                   Khaing Lon Gems CoLtd    1.549539e+09
# 26  Myanmar Win Gate Gems Jewellery Mining    1.451212e+09
# 2                  Chaow Brothers Gemstone    1.363078e+09
# 44                        Unity Gems CoLtd    1.145670e+09
# 43     Thiha Three Brothers Gems Jewellery    1.114360e+09
# 4                           Emerald Garden    1.107947e+09
# 11             Kan Pwint Oo Gems Jewellery    1.039928e+09
# 17                                Kyay Lin    5.770461e+08
# 8               Green Light Treasure CoLtd    4.444102e+08
# 48           Yadanar San Shwin Gems Co Ltd    3.657094e+08
# 18                           Kyay Sin Phyu    2.811620e+08
# 46                        Xie Family CoLtd    2.123807e+08
# 5            Golden Wallet Jewellery CoLtd    8.165766e+07
# 29                      NILAR YOMA TRADING    4.102569e+07
# 22            Myanma Gon Yi Gems Jewellery    0.000000e+00
# 21                        Mega Stone CoLtd    0.000000e+00

# %%
df_gemsjade = pd.merge(df_gemsjade, company_totals, on='Company_name_cl')

# %% [markdown]
# ## Remove negative payments for Sankey

# %%
df_gemsjade = df_gemsjade[df_gemsjade["value_reported"] > 0]
df_gemsjade = df_gemsjade.sort_values(by=['total_payments'], ascending=False)
df_gemsjade.drop(['Unnamed: 0'], axis=1)
df_gemsjade
# Out:
#                           Company_name_cl  Unnamed: 0  \
# 678  Companies not in EITI Reconciliation         NaN
# 670  Companies not in EITI Reconciliation         NaN
# 664  Companies not in EITI Reconciliation         NaN
# 665  Companies not in EITI Reconciliation         NaN
# 666  Companies not in EITI Reconciliation         NaN
# 667  Companies not in EITI Reconciliation         NaN
# 668  Companies not in EITI Reconciliation         NaN
# 669  Companies not in EITI Reconciliation         NaN
# 671  Companies not in EITI Reconciliation         NaN
# 672  Companies not in EITI Reconciliation         NaN
# 673  Companies not in EITI Reconciliation         NaN
# 674  Companies not in EITI Reconciliation         NaN
# 675  Companies not in EITI Reconciliation         NaN
# 676  Companies not in EITI Reconciliation         NaN
# 677  Companies not in EITI Reconciliation         NaN
# 663  Companies not in EITI Reconciliation         NaN
# 1               Great Genesis Gems Co Ltd         0.0
# 0               Great Genesis Gems Co Ltd         0.0
# 2               Great Genesis Gems Co Ltd         0.0
# 4               Great Genesis Gems Co Ltd         0.0
# 7               Great Genesis Gems Co Ltd         0.0
# 8               Great Genesis Gems Co Ltd         0.0
# 9               Great Genesis Gems Co Ltd         0.0
# 14            Sein Lom Taung Tan Gems Ltd         0.0
# 13            Sein Lom Taung Tan Gems Ltd         0.0
# 15            Sein Lom Taung Tan Gems Ltd         0.0
# 643  entity    3.600000e+08    4.444102e+08
# 645  entity    5.394195e+07    4.444102e+08
# 499  entity    5.178500e+06    3.657094e+08
# 500  entity    3.481000e+08    3.657094e+08
# 503  entity    5.000000e+05    3.657094e+08
# 502  entity    1.023524e+07    3.657094e+08
# 496  entity    1.695623e+06    3.657094e+08
# 420  entity    6.570000e+05    2.811620e+08
# 422  entity    2.805050e+08    2.811620e+08
# 651  entity    1.731675e+07    2.123807e+08
# 650  entity    1.097975e+08    2.123807e+08
# 661  entity    6.344284e+06    2.123807e+08
# 659  entity    3.162464e+06    2.123807e+08
# 658  entity    7.039204e+07    2.123807e+08
# 657  entity    2.226478e+06    2.123807e+08
# 652  entity    3.141266e+06    2.123807e+08
# 509  entity    3.646210e+06    8.165766e+07
# 511  entity    6.794200e+06    8.165766e+07
# 513  entity    1.190000e+07    8.165766e+07
# 515  entity    5.462487e+07    8.165766e+07
# 516  entity    4.096188e+06    8.165766e+07
# 518  entity    5.961940e+05    8.165766e+07
# 539  entity    2.000000e+06    4.102569e+07
# 535  entity    3.773920e+05    4.102569e+07
# 537  entity    8.928500e+05    4.102569e+07
# 541  entity    3.775545e+07    4.102569e+07
#
# [378 rows x 8 columns]

# %%
df_gemsjade_summary = df_gemsjade[df_gemsjade['Company_name_cl'] != 'Companies not in EITI Reconciliation']
df_gemsjade_summary = df_gemsjade_summary.groupby(['name_of_revenue_stream','paid_to','target_type','type']).sum().reset_index()
df_gemsjade_summary['Company_name_cl'] = 'Companies in EITI Reconciliation'
df_gemsjade_summary = df_gemsjade[df_gemsjade['Company_name_cl'] == 'Companies not in EITI Reconciliation'] \
                        .append(df_gemsjade_summary)
df_gemsjade_summary
# Out:
#                           Company_name_cl  Unnamed: 0  \
# 678  Companies not in EITI Reconciliation         NaN
# 670  Companies not in EITI Reconciliation         NaN
# 664  Companies not in EITI Reconciliation         NaN
# 665  Companies not in EITI Reconciliation         NaN
# 666  Companies not in EITI Reconciliation         NaN
# 667  Companies not in EITI Reconciliation         NaN
# 668  Companies not in EITI Reconciliation         NaN
# 669  Companies not in EITI Reconciliation         NaN
# 671  Companies not in EITI Reconciliation         NaN
# 672  Companies not in EITI Reconciliation         NaN
# 673  Companies not in EITI Reconciliation         NaN
# 674  Companies not in EITI Reconciliation         NaN
# 675  Companies not in EITI Reconciliation         NaN
# 676  Companies not in EITI Reconciliation         NaN
# 677  Companies not in EITI Reconciliation         NaN
# 663  Companies not in EITI Reconciliation         NaN
# 0        Companies in EITI Reconciliation         0.0
# 1        Companies in EITI Reconciliation         0.0
# 2        Companies in EITI Reconciliation         0.0
# 3        Companies in EITI Reconciliation         0.0
# 4        Companies in EITI Reconciliation         0.0
# 5        Companies in EITI Reconciliation         0.0
# 6        Companies in EITI Reconciliation         0.0
# 7        Companies in EITI Reconciliation         0.0
# 8        Companies in EITI Reconciliation         0.0
# 9        Companies in EITI Reconciliation         0.0
# 10       Companies in EITI Reconciliation         0.0
# 11       Companies in EITI Reconciliation         0.0
#
#          name_of_revenue_stream                      paid_to target_type  \
# 678           Capital Gains Tax  Internal Revenue Department         NaN
# 670   Emporium Fees / Sale Fees      Myanmar Gems Enterprise         NaN
# 664                  Sale Split      Myanmar Gems Enterprise         NaN
# 665             Sales Royalties      Myanmar Gems Enterprise         NaN
# 666                Service Fees      Myanmar Gems Enterprise         NaN
# 667                 Permit Fees      Myanmar Gems Enterprise         NaN
# 668              Incentive Fees      Myanmar Gems Enterprise         NaN
# 669  Other significant payments      Myanmar Gems Enterprise         NaN
# 671                  Sale Split      Myanmar Gems Enterprise         NaN
# 672              Commercial Tax      Myanmar Gems Enterprise         NaN
# 673              Customs Duties           Customs Department         NaN
# 674              Commercial Tax  Internal Revenue Department         NaN
# 675                   Royalties  Internal Revenue Department         NaN
# 676                  Income Tax  Internal Revenue Department         NaN
# 677             Withholding Tax  Internal Revenue Department         NaN
# 663        Production Royalties      Myanmar Gems Enterprise         NaN
# 0                Commercial Tax  Internal Revenue Department
# 1                Commercial Tax      Myanmar Gems Enterprise
# 2          Corporate Income Tax  Internal Revenue Department
# 3                Customs Duties           Customs Department
# 4                 Emporium Fees             Central Comittee
# 5                Incentive Fees      Myanmar Gems Enterprise
# 6                   Permit Fees      Myanmar Gems Enterprise
# 7          Production Royalties          Department of Mines
# 8          Production Royalties      Myanmar Gems Enterprise
# 9                    Sale Split      Myanmar Gems Enterprise
# 10              Sales Royalties  Internal Revenue Department
# 11              Sales Royalties      Myanmar Gems Enterprise
#
#      total_payments    type  value_reported
# 678    4.796367e+11  entity    3.370824e+07
# 670    4.796367e+11  entity    2.987473e+09
# 664    4.796367e+11  entity    1.225653e+08
# 665    4.796367e+11  entity    1.593382e+09
# 666    4.796367e+11  entity    6.827346e+08
# 667    4.796367e+11  entity    8.949448e+10
# 668    4.796367e+11  entity    2.133446e+08
# 669    4.796367e+11  entity    2.637094e+09
# 671    4.796367e+11  entity    5.272471e+09
# 672    4.796367e+11  entity    4.135332e+10
# 673    4.796367e+11  entity    2.985924e+09
# 674    4.796367e+11  entity    2.440801e+11
# 675    4.796367e+11  entity    7.612310e+10
# 676    4.796367e+11  entity    4.377920e+09
# 677    4.796367e+11  entity    5.128104e+07
# 663    4.796367e+11  entity    7.627853e+09
# 0      7.360385e+10  entity    6.770876e+09
# 1      2.157511e+11  entity    6.731475e+10
# 2      1.858162e+11  entity    6.134533e+09
# 3      1.115549e+11  entity    3.318099e+09
# 4      2.101422e+11  entity    4.343231e+09
# 5      1.819944e+11  entity    2.815064e+09
# 6      1.340107e+11  entity    1.693100e+10
# 7      4.634243e+10  entity    3.110405e+09
# 8      1.624173e+11  entity    6.500333e+09
# 9      1.880478e+11  entity    7.479671e+10
# 10     1.271075e+10  entity    1.819718e+09
# 11     1.905194e+11  entity    2.217756e+10

# %% [markdown]
# ## Prepare Source-Target-Value dataframe

# %%
links_companies = pd.DataFrame(columns=['source','target','value','type'])

# %%
to_append = df_gemsjade.groupby(['name_of_revenue_stream','paid_to'],as_index=False)['type','value_reported','total_payments'].sum()

#to_append["target"] = "Myanmar Gems Enterprise"
to_append.rename(columns = {'name_of_revenue_stream':'source', 'value_reported' : 'value', 'paid_to': 'target'}, inplace = True)

to_append = to_append.sort_values(by=['value'], ascending = False)
to_append['target_type'] = 'entity'

links_companies = pd.concat([links_companies,to_append])

print(to_append['value'].sum())
links_companies
# Out:
# 695668986359.0
#                         source                       target target_type  \
# 1               Commercial Tax  Internal Revenue Department      entity
# 2               Commercial Tax      Myanmar Gems Enterprise      entity
# 10                 Permit Fees      Myanmar Gems Enterprise      entity
# 14                  Sale Split      Myanmar Gems Enterprise      entity
# 13                   Royalties  Internal Revenue Department      entity
# 16             Sales Royalties      Myanmar Gems Enterprise      entity
# 12        Production Royalties      Myanmar Gems Enterprise      entity
# 4               Customs Duties           Customs Department      entity
# 3         Corporate Income Tax  Internal Revenue Department      entity
# 8                   Income Tax  Internal Revenue Department      entity
# 5                Emporium Fees             Central Comittee      entity
# 11        Production Royalties          Department of Mines      entity
# 7               Incentive Fees      Myanmar Gems Enterprise      entity
# 6    Emporium Fees / Sale Fees      Myanmar Gems Enterprise      entity
# 9   Other significant payments      Myanmar Gems Enterprise      entity
# 15             Sales Royalties  Internal Revenue Department      entity
# 17                Service Fees      Myanmar Gems Enterprise      entity
# 18             Withholding Tax  Internal Revenue Department      entity
# 0            Capital Gains Tax  Internal Revenue Department      entity
#
#     total_payments type         value
# 1     5.532406e+11  NaN  2.508509e+11
# 2     6.953878e+11  NaN  1.086681e+11
# 10    6.136474e+11  NaN  1.064255e+11
# 14    1.147321e+12  NaN  8.019175e+10
# 13    4.796367e+11  NaN  7.612310e+10
# 16    6.701561e+11  NaN  2.377094e+10
# 12    6.420540e+11  NaN  1.412819e+10
# 4     5.911916e+11  NaN  6.304023e+09
# 3     1.858162e+11  NaN  6.134533e+09
# 8     4.796367e+11  NaN  4.377920e+09
# 5     2.101422e+11  NaN  4.343231e+09
# 11    4.634243e+10  NaN  3.110405e+09
# 7     6.616311e+11  NaN  3.028408e+09
# 6     4.796367e+11  NaN  2.987473e+09
# 9     4.796367e+11  NaN  2.637094e+09
# 15    1.271075e+10  NaN  1.819718e+09
# 17    4.796367e+11  NaN  6.827346e+08
# 18    4.796367e+11  NaN  5.128104e+07
# 0     4.796367e+11  NaN  3.370824e+07

# %%
## Page 239 of 2015-16 Report. Appendix 8: SOEs reconciliation sheets
append_dict_transfers = [{'source': 'Myanmar Gems Enterprise', 'type': 'entity',
                       'target': 'Corporate Income Tax (Inter-Government)', 'value': 53788313000 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity', 
                       'target': 'Commercial Tax (Inter-Government)', 'value': 15000000 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity',
                       'target': 'Production Royalties (Inter-Government)', 'value': 17249087176 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity', 
                       'target': 'State Contribution (Inter-Government)', 'value': 46833942000 },
                         
                         
                         {'source': 'Corporate Income Tax (Inter-Government)', 'target_type': 'entity',
                       'target': 'Internal Revenue Department', 'value': 53788313000 },
                         
                         {'source': 'Commercial Tax (Inter-Government)', 'target_type': 'entity', 
                       'target': 'Internal Revenue Department', 'value': 15000000 },
                         
                         {'source': 'Production Royalties (Inter-Government)', 'target_type': 'entity',
                       'target': 'Department of Mines', 'value': 17249087176 },
                         
                         {'source': 'State Contribution (Inter-Government)', 'target_type': 'entity', 
                       'target': 'Ministry of Planning and Finance', 'value': 46833942000 },
                         
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity',
                       'target': 'Other Accounts', 'value': 107705106000 },
                        
                        
                         {'source': 'Other Accounts', 'target_type': 'entity',
                       'target': 'Ministry of Planning and Finance', 'value': 107705106000 },
                        
                        {'source': 'Internal Revenue Department', 'type': 'entity', 'target_type': 'entity',
                       'target': 'Ministry of Planning and Finance', 'value': 393194500968 }]



append_dict_transfers_df = pd.DataFrame(append_dict_transfers)

links_summary = pd.concat([links_companies, append_dict_transfers_df])
links_govt = append_dict_transfers_df
#links = pd.concat([links, append_dict_transfers_df])

# %%
to_append = df_gemsjade.groupby(['name_of_revenue_stream','Company_name_cl','type'],as_index=False) \
    ['value_reported','total_payments'] \
    .agg({'value_reported':sum,'total_payments':'first'})
to_append.rename(columns = {'Company_name_cl':'source','name_of_revenue_stream':'target', 'value_reported' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['total_payments'], ascending = False)
links_companies = pd.concat([links_companies,to_append])

print(to_append['value'].sum())
#links
to_append
# Out:
# 695668986359.0
#                          target                                source    type  \
# 0             Capital Gains Tax  Companies not in EITI Reconciliation  entity
# 87               Customs Duties  Companies not in EITI Reconciliation  entity
# 359                Service Fees  Companies not in EITI Reconciliation  entity
# 322             Sales Royalties  Companies not in EITI Reconciliation  entity
# 282                  Sale Split  Companies not in EITI Reconciliation  entity
# 279                   Royalties  Companies not in EITI Reconciliation  entity
# 235        Production Royalties  Companies not in EITI Reconciliation  entity
# 197                 Permit Fees  Companies not in EITI Reconciliation  entity
# 194  Other significant payments  Companies not in EITI Reconciliation  entity
# 193                  Income Tax  Companies not in EITI Reconciliation  entity
# 157              Incentive Fees  Companies not in EITI Reconciliation  entity
# 154   Emporium Fees / Sale Fees  Companies not in EITI Reconciliation  entity
# 360             Withholding Tax  Companies not in EITI Reconciliation  entity
# 4                Commercial Tax  Companies not in EITI Reconciliation  entity
# 324             Sales Royalties             Great Genesis Gems Co Ltd  entity
# 238        Production Royalties             Great Genesis Gems Co Ltd  entity
# 159              Incentive Fees             Great Genesis Gems Co Ltd  entity
# 112               Emporium Fees             Great Genesis Gems Co Ltd  entity
# 55         Corporate Income Tax             Great Genesis Gems Co Ltd  entity
# 284                  Sale Split             Great Genesis Gems Co Ltd  entity
# 7                Commercial Tax             Great Genesis Gems Co Ltd  entity
# 347             Sales Royalties           Sein Lom Taung Tan Gems Ltd  entity
# 307                  Sale Split           Sein Lom Taung Tan Gems Ltd  entity
# 74         Corporate Income Tax           Sein Lom Taung Tan Gems Ltd  entity
# 181              Incentive Fees           Sein Lom Taung Tan Gems Ltd  entity
# 140               Emporium Fees           Sein Lom Taung Tan Gems Ltd  entity
# 266        Production Royalties           Sein Lom Taung Tan Gems Ltd  entity
# 222                 Permit Fees           Sein Lom Taung Tan Gems Ltd  entity
# 35               Commercial Tax           Sein Lom Taung Tan Gems Ltd  entity
# 43               Commercial Tax            Wai Aung Gabar Gems Co Ltd  entity
# ..                          ...                                   ...     ...
# 57         Corporate Income Tax            Green Light Treasure CoLtd  entity
# 240        Production Royalties            Green Light Treasure CoLtd  entity
# 114               Emporium Fees            Green Light Treasure CoLtd  entity
# 9                Commercial Tax            Green Light Treasure CoLtd  entity
# 200                 Permit Fees            Green Light Treasure CoLtd  entity
# 285                  Sale Split            Green Light Treasure CoLtd  entity
# 230  3.481000e+08    3.657094e+08
# 250  6.570000e+05    2.811620e+08
# 208  2.805050e+08    2.811620e+08
# 356  1.731675e+07    2.123807e+08
# 316  1.097975e+08    2.123807e+08
# 44   7.039204e+07    2.123807e+08
# 190  2.226478e+06    2.123807e+08
# 149  3.141266e+06    2.123807e+08
# 80   3.162464e+06    2.123807e+08
# 103  6.344284e+06    2.123807e+08
# 54   4.096188e+06    8.165766e+07
# 6    5.462487e+07    8.165766e+07
# 88   5.961940e+05    8.165766e+07
# 237  6.794200e+06    8.165766e+07
# 198  1.190000e+07    8.165766e+07
# 111  3.646210e+06    8.165766e+07
# 132  3.773920e+05    4.102569e+07
# 215  2.000000e+06    4.102569e+07
# 27   3.775545e+07    4.102569e+07
# 258  8.928500e+05    4.102569e+07
#
# [361 rows x 5 columns]

# %%
to_append = df_gemsjade_summary.groupby(['name_of_revenue_stream','Company_name_cl','type'],as_index=False) \
    ['value_reported','total_payments'] \
    .agg({'value_reported':sum,'total_payments':'first'})
to_append.rename(columns = {'Company_name_cl':'source','name_of_revenue_stream':'target', 'value_reported' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['total_payments'], ascending = False)
links_summary = pd.concat([links_summary,to_append])
links_summary
# Out:
#                                      source  \
# 1                            Commercial Tax
# 2                            Commercial Tax
# 10                              Permit Fees
# 14                               Sale Split
# 13                                Royalties
# 16                          Sales Royalties
# 12                     Production Royalties
# 4                            Customs Duties
# 3                      Corporate Income Tax
# 8                                Income Tax
# 5                             Emporium Fees
# 11                     Production Royalties
# 7                            Incentive Fees
# 6                 Emporium Fees / Sale Fees
# 9                Other significant payments
# 15                          Sales Royalties
# 17                             Service Fees
# 18                          Withholding Tax
# 0                         Capital Gains Tax
# 0                   Myanmar Gems Enterprise
# 1                   Myanmar Gems Enterprise
# 2                   Myanmar Gems Enterprise
# 3                   Myanmar Gems Enterprise
# 4   Corporate Income Tax (Inter-Government)
# 5         Commercial Tax (Inter-Government)
# 6   Production Royalties (Inter-Government)
# 7     State Contribution (Inter-Government)
# 8                   Myanmar Gems Enterprise
# 9                            Other Accounts
# 10              Internal Revenue Department
# 0      Companies not in EITI Reconciliation
# 9      Companies not in EITI Reconciliation
# 21     Companies not in EITI Reconciliation
# 20     Companies not in EITI Reconciliation
# 18     Companies not in EITI Reconciliation
# 16     Companies not in EITI Reconciliation
# 15     Companies not in EITI Reconciliation
# 13     Companies not in EITI Reconciliation
# 10     Companies not in EITI Reconciliation
# 11     Companies not in EITI Reconciliation
# 7      Companies not in EITI Reconciliation
# 5      Companies not in EITI Reconciliation
# 2      Companies not in EITI Reconciliation
# 22     Companies not in EITI Reconciliation
# 6          Companies in EITI Reconciliation
# 17         Companies in EITI Reconciliation
# 3          Companies in EITI Reconciliation
# 8          Companies in EITI Reconciliation
# 12         Companies in EITI Reconciliation
# 4          Companies in EITI Reconciliation
# 1          Companies in EITI Reconciliation
# 14         Companies in EITI Reconciliation
# 19         Companies in EITI Reconciliation
#
#                                      target target_type  total_payments  \
# 1               Internal Revenue Department      entity    5.532406e+11
# 2                   Myanmar Gems Enterprise      entity    6.953878e+11
# 10                  Myanmar Gems Enterprise      entity    6.136474e+11
# 14                  Myanmar Gems Enterprise      entity    1.147321e+12
# 13              Internal Revenue Department      entity    4.796367e+11
# 16                  Myanmar Gems Enterprise      entity    6.701561e+11
# 12                  Myanmar Gems Enterprise      entity    6.420540e+11
# 4                        Customs Department      entity    5.911916e+11
# 3               Internal Revenue Department      entity    1.858162e+11
# 8               Internal Revenue Department      entity    4.796367e+11
# 5                          Central Comittee      entity    2.101422e+11
# 11                      Department of Mines      entity    4.634243e+10
# 7                   Myanmar Gems Enterprise      entity    6.616311e+11
# 6                   Myanmar Gems Enterprise      entity    4.796367e+11
# 9                   Myanmar Gems Enterprise      entity    4.796367e+11
# 15              Internal Revenue Department      entity    1.271075e+10
# 17                  Myanmar Gems Enterprise      entity    4.796367e+11
# 18              Internal Revenue Department      entity    4.796367e+11
# 0               Internal Revenue Department      entity    4.796367e+11
# 0   Corporate Income Tax (Inter-Government)         NaN             NaN
# 1         Commercial Tax (Inter-Government)         NaN             NaN
# 2   Production Royalties (Inter-Government)         NaN             NaN
# 3     State Contribution (Inter-Government)         NaN             NaN
# 4               Internal Revenue Department      entity             NaN
# 5               Internal Revenue Department      entity             NaN
# 6                       Department of Mines      entity             NaN
# 7          Ministry of Planning and Finance      entity             NaN
# 8                            Other Accounts         NaN             NaN
# 9          Ministry of Planning and Finance      entity             NaN
# 10         Ministry of Planning and Finance      entity             NaN
# 0                         Capital Gains Tax         NaN    4.796367e+11
# 9                            Incentive Fees         NaN    4.796367e+11
# 21                             Service Fees         NaN    4.796367e+11
# 20                          Sales Royalties         NaN    4.796367e+11
# 18                               Sale Split         NaN    4.796367e+11
# 16                                Royalties         NaN    4.796367e+11
# 15                     Production Royalties         NaN    4.796367e+11
# 13                              Permit Fees         NaN    4.796367e+11
# 10                               Income Tax         NaN    4.796367e+11
# 11               Other significant payments         NaN    4.796367e+11
# 7                 Emporium Fees / Sale Fees         NaN    4.796367e+11
# 5                            Customs Duties         NaN    4.796367e+11
# 2                            Commercial Tax         NaN    4.796367e+11
# 22                          Withholding Tax         NaN    4.796367e+11
# 6                             Emporium Fees         NaN    2.101422e+11
# 17                               Sale Split         NaN    1.880478e+11
# 3                      Corporate Income Tax         NaN    1.858162e+11
# 8                            Incentive Fees         NaN    1.819944e+11
# 12                              Permit Fees         NaN    1.340107e+11
# 4                            Customs Duties         NaN    1.115549e+11
# 1                            Commercial Tax         NaN    7.360385e+10
# 14                     Production Royalties         NaN    4.634243e+10
# 19                          Sales Royalties         NaN    1.271075e+10
#
#       type         value
# 1      NaN  2.508509e+11
# 2      NaN  1.086681e+11
# 10     NaN  1.064255e+11
# 14     NaN  8.019175e+10
# 13     NaN  7.612310e+10
# 16     NaN  2.377094e+10
# 12     NaN  1.412819e+10
# 4      NaN  6.304023e+09
# 3      NaN  6.134533e+09
# 8      NaN  4.377920e+09
# 5      NaN  4.343231e+09
# 11     NaN  3.110405e+09
# 7      NaN  3.028408e+09
# 6      NaN  2.987473e+09
# 9      NaN  2.637094e+09
# 15     NaN  1.819718e+09
# 17     NaN  6.827346e+08
# 18     NaN  5.128104e+07
# 0      NaN  3.370824e+07
# 0   entity  5.378831e+10
# 1   entity  1.500000e+07
# 2   entity  1.724909e+10
# 3   entity  4.683394e+10
# 4      NaN  5.378831e+10
# 5      NaN  1.500000e+07
# 6      NaN  1.724909e+10
# 7      NaN  4.683394e+10
# 8   entity  1.077051e+11
# 9      NaN  1.077051e+11
# 10  entity  3.931945e+11
# 0   entity  3.370824e+07
# 9   entity  2.133446e+08
# 21  entity  6.827346e+08
# 20  entity  1.593382e+09
# 18  entity  5.395037e+09
# 16  entity  7.612310e+10
# 15  entity  7.627853e+09
# 13  entity  8.949448e+10
# 10  entity  4.377920e+09
# 11  entity  2.637094e+09
# 7   entity  2.987473e+09
# 5   entity  2.985924e+09
# 2   entity  2.854334e+11
# 22  entity  5.128104e+07
# 6   entity  4.343231e+09
# 17  entity  7.479671e+10
# 3   entity  6.134533e+09
# 8   entity  2.815064e+09
# 12  entity  1.693100e+10
# 4   entity  3.318099e+09
# 1   entity  7.408562e+10
# 14  entity  9.610738e+09
# 19  entity  2.399728e+10

# %%
def prep_nodes_links(links):
    unique_source = links['source'].unique()
    unique_targets = links['target'].unique()

    unique_source = pd.merge(pd.DataFrame(unique_source), links, left_on=0, right_on='source', how='left')
    unique_source = unique_source.filter([0,'type'])
    unique_targets = pd.merge(pd.DataFrame(unique_targets), links, left_on=0, right_on='target', how='left')
    unique_targets = unique_targets.filter([0,'target_type'])
    unique_targets.rename(columns = {'target_type':'type'}, inplace = True)

    unique_list = pd.concat([unique_source[0], unique_targets[0]]).unique()

    unique_list = pd.merge(pd.DataFrame(unique_list), \
                           pd.concat([unique_source, unique_targets]), left_on=0, right_on=0, how='left')

    unique_list.drop_duplicates(subset=0, keep='first', inplace=True)

    replace_dict = {k: v for v, k in enumerate(unique_list[0])}
    unique_list
    return [unique_list,replace_dict]


#unique_list = pd.concat([links['source'], links['target']]).unique()
#replace_dict = {k: v for v, k in enumerate(unique_list)}

# %%
[unique_list_summary,replace_dict_summary] = prep_nodes_links(links_summary)
[unique_list_companies,replace_dict_companies] = prep_nodes_links(links_companies)
[unique_list_govt,replace_dict_govt] = prep_nodes_links(links_govt)

# %%
def write_nodes_links(filename,unique_list,replace_dict,links):
    links_replaced = links.replace({"source": replace_dict,"target": replace_dict})
    nodes = pd.DataFrame(unique_list)
    nodes.rename(columns = {0:'name'}, inplace = True)
    nodes_json= pd.DataFrame(nodes).to_json(orient='records')
    links_json= pd.DataFrame(links_replaced).to_json(orient='records')
    
    data = { 'links' : json.loads(links_json), 'nodes' : json.loads(nodes_json) }
    data_json = json.dumps(data)
    data_json = data_json.replace("\\","")
    #print(data_json)
    #with open('sankey_data.json', 'w') as outfile:
    #    json.dump(data_json, outfile)

    text_file = open(filename + ".json", "w")
    text_file.write(data_json)
    text_file.close()

# %%
write_nodes_links("sankey_data_2015-16_summary",unique_list_summary,replace_dict_summary,links_summary)
write_nodes_links("sankey_data_2015-16_companies",unique_list_companies,replace_dict_companies,links_companies)
write_nodes_links("sankey_data_2015-16_govt",unique_list_govt,replace_dict_govt,links_govt)
