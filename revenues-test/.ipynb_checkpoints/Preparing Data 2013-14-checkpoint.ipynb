# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_csv('data/eiti-summary-company-payments.csv')

# %%
df = df[df['country'] == "Myanmar"]

# %%
df.head()
# Out:
#                         created                   changed  country iso3  year  \
# 31969  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
# 31970  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
# 31971  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
# 31972  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
# 31973  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
#
#         start_date      end_date                   company_name  gfs_code  \
# 31969  Apr 1, 2013  Mar 31, 2014  Petronas Carigali Myanmar Inc   1112-E1
# 31970  Apr 1, 2013  Mar 31, 2014  Petronas Carigali Myanmar Inc   1415-E1
# 31971  Apr 1, 2013  Mar 31, 2014  Petronas Carigali Myanmar Inc  1415-E32
# 31972  Apr 1, 2013  Mar 31, 2014  Petronas Carigali Myanmar Inc  1415-E32
# 31973  Apr 1, 2013  Mar 31, 2014  Petronas Carigali Myanmar Inc  1415-E32
#
#                                          gfs_description  \
# 31969  Ordinary taxes on income, profits and capital ...
# 31970                                          Royalties
# 31971        Delivered/paid to state-owned enterprise(s)
# 31972        Delivered/paid to state-owned enterprise(s)
# 31973        Delivered/paid to state-owned enterprise(s)
#
#                                   name_of_revenue_stream currency_code  \
# 31969  Revenue Stream: 1112E1 [Ordinary taxes on inco...           MMK
# 31970     Revenue Stream: 1415E1 [Royalties] - Royalties           MMK
# 31971  Revenue Stream: 1415E32 [Delivered/paid to sta...           MMK
# 31972  Revenue Stream: 1415E32 [Delivered/paid to sta...           MMK
# 31973  Revenue Stream: 1415E32 [Delivered/paid to sta...           MMK
#
#        currency_rate  value_reported  value_reported_as_USD  \
# 31969       960.5121    4.017128e+10             41822777.0
# 31970       960.5121    1.407288e+11            146514378.0
# 31971       960.5121    6.139777e+11            639219143.0
# 31972       960.5121    1.208082e+11            125774746.0
# 31973       960.5121    4.923598e+09              5126014.0
#
#                                       reporting_url
# 31969  https://eiti.org/api/v1.0/organisation/31689
# 31970  https://eiti.org/api/v1.0/organisation/31689
# 31971  https://eiti.org/api/v1.0/organisation/31689
# 31972  https://eiti.org/api/v1.0/organisation/31689
# 31973  https://eiti.org/api/v1.0/organisation/31689

# %% [markdown]
# ## Clean data

# %%
df["company_name"].unique()
# Out:
# array(['Petronas Carigali Myanmar Inc', 'TOTAL',
#        'Daewoo International Corporation', 'PTT Exploration & Production',
#        'Goldpetrol Co Ltd', 'MPRL E&P Pte Ltd', 'Nippon Oil', 'UNOCAL',
#        'Chinnery Assets Ltd', 'SNOG Pte Ltd', 'Eternal Mining Company Ltd',
#        'Kayah State Mining Production Co. (KMPC)',
#        'Myanmar Pongpipat Company Limited', 'Nobel Gold',
#        'Tha Byu Mining Co., Ltd.', 'Win Myint Mo Industries Co.,Ltd.',
#        'DELCO (Developers Enterepreneurs Liaison Construction Organizers Limited',
#        'GPS Joint Venture Co., Ltd.', 'Ngwe Yi Pale Mining Co., Ltd',
#        'Max Myanmar Manufacturing Co.,',
#        'Triple A Cement International Co., Ltd',
#        'Myanmar Wanbao Mining Copper', 'Myanmar Yang Tse Copper Ltd',
#        'CNMC Nickel Co Ltd. (MCNICO) (Tagaung Taung Nickel project)',
#        'Great Genesis Gems Co., Ltd.', 'MYANMAR IMPERIAL JADE',
#        'Richest Gems Co., Ltd', 'LINN LETT WIN YADANAR GEMS',
#        'EVER WINNER GEMS', 'AUNG HEIN MIN GEMS', 'Wai Aung Ka Bar',
#        'Ya Zar Htar Ni', 'SHWE YWET HLWAR GEMS', 'Kyauk Sein Na Gar',
#        'YADANAR YAUNG CHI GEMS', 'Jade Mountain Gems', 'THI RAW MANI GEMS',
#        'Kyaik International', 'MYAT YAMON GEMS', 'WINN LEI YADANA',
#        'Myanmar Si Thu', '111', 'Sein Lone Taung Tan',
#        'SHINING STAR LIGHT GEMS', 'Khin Zaw Aung and Brothers',
#        'Xie Family', 'Aye Yar Kyauk Sein', 'WAI FAMILY GEMS',
#        'AYEYAR YANDANAR GEMS', 'A Myo Thar Kyi Pwar Toe Tat Yay',
#        'SHWE WAH MYAY (MANDALAY)', 'Ya Da Nar Taung Tan',
#        'NAY LA PWINT GEMS', 'TREASURE WHITE LOTUS GEMS'], dtype=object)

# %%
companies_info_df = pd.read_csv('data/eiti_summary_companies_cleaned.csv')

# %%
companies_info_df.head()
# Out:
#                          Legal name     Identification  \
# 0     Petronas Carigali Myanmar Inc                 NC
# 1                             TOTAL  24FC of 1992-1993
# 2  Daewoo International Corporation   1 FC / 2002-2003
# 3      PTT Exploration & Production              84 FC
# 4                 Goldpetrol Co Ltd             173 FC
#
#                                  Company_name_cl Identification_cl Commodities
# 0  PETRONAS CARIGALI MYANMAR INC.(BRANCH OFFICE)    16FC/2011-2012   Oil & Gas
# 1            TOTAL E & P MYANMAR (YANGON BRANCH)    24FC/1992-1993   Oil & Gas
# 2  Posco Daewoo Corporation (Myanmar E&P Office)     1FC/2002-2003   Oil & Gas
# 3       PTTEP International Ltd. (Yangon Branch)    84FC/1995-1996   Oil & Gas
# 4                              Goldpetrol Co Ltd            173 FC   Oil & Gas

# %%
df = pd.merge(df, companies_info_df, left_on='company_name', right_on='Legal name')

# %%
df[df['Commodities'] == 'Gems & Jade']['name_of_revenue_stream'].unique()
# Out:
# array(['Revenue Stream: 1415E1 [Royalties] - Royalties',
#        'Revenue Stream: 1415E32 [Delivered/paid to state-owned enterprise(s)] - Sale Split',
#        'Revenue Stream: 1415E32 [Delivered/paid to state-owned enterprise(s)] - Emporium Fees / Sale Fees',
#        'Revenue Stream: 1422E [Administrative fees for government services] - Supervision Fees',
#        'Revenue Stream: 1415E5 [Other rent payments] - Other significant payments (&gt; 50,000 USD)'], dtype=object)

# %%
df[df['Commodities'] == 'Gems & Jade']['gfs_description'].unique()
# Out:
# array(['Royalties', 'Delivered/paid to state-owned enterprise(s)',
#        'Administrative fees for government services', 'Other rent payments'], dtype=object)

# %%
df['revenue_stream_short'] = df['name_of_revenue_stream'].str.split(' - ').str[1]

# %%
df_gemsjade = df[df['Commodities'] == 'Gems & Jade']
df_gemsjade['type'] = 'entity'
df_gemsjade['target_type'] = ''
# Out:
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df_gemsjade.head()
# Out:
#                      created                   changed  country iso3  year  \
# 76  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
# 77  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
# 78  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
# 79  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
# 80  2017-02-13T07:00:42+0000  2017-02-13T07:00:42+0000  Myanmar  MMR  2014
#
#      start_date      end_date                  company_name  gfs_code  \
# 76  Apr 1, 2013  Mar 31, 2014  Great Genesis Gems Co., Ltd.   1415-E1
# 77  Apr 1, 2013  Mar 31, 2014  Great Genesis Gems Co., Ltd.  1415-E32
# 78  Apr 1, 2013  Mar 31, 2014  Great Genesis Gems Co., Ltd.  1415-E32
# 79  Apr 1, 2013  Mar 31, 2014  Great Genesis Gems Co., Ltd.    1422-E
# 80  Apr 1, 2013  Mar 31, 2014         MYANMAR IMPERIAL JADE   1415-E1
#
#                                 gfs_description     ...      \
# 76                                    Royalties     ...
# 77  Delivered/paid to state-owned enterprise(s)     ...
# 78  Delivered/paid to state-owned enterprise(s)     ...
# 79  Administrative fees for government services     ...
# 80                                    Royalties     ...
#
#    value_reported_as_USD                                 reporting_url  \
# 76             4419839.0  https://eiti.org/api/v1.0/organisation/31716
# 77            15621836.0  https://eiti.org/api/v1.0/organisation/31716
# 78              400000.0  https://eiti.org/api/v1.0/organisation/31716
# 79              397785.0  https://eiti.org/api/v1.0/organisation/31716
# 80             3988599.0  https://eiti.org/api/v1.0/organisation/31717
#
#                       Legal name   Identification  \
# 76  Great Genesis Gems Co., Ltd.    978/2005-2006
# 77  Great Genesis Gems Co., Ltd.    978/2005-2006
# 78  Great Genesis Gems Co., Ltd.    978/2005-2006
# 79  Great Genesis Gems Co., Ltd.    978/2005-2006
# 80         MYANMAR IMPERIAL JADE  919 / 1996-1997
#
#                                       Company_name_cl Identification_cl  \
# 76                 GREAT GENESIS GEMS COMPANY LIMITED     978/2005-2006
# 77                 GREAT GENESIS GEMS COMPANY LIMITED     978/2005-2006
# 78                 GREAT GENESIS GEMS COMPANY LIMITED     978/2005-2006
# 79                 GREAT GENESIS GEMS COMPANY LIMITED     978/2005-2006
# 80  MYANMAR IMPERIAL JADE (GEMS & JEWELLERY) COMPA...     919/1996-1997
#
#     Commodities       revenue_stream_short    type target_type
# 76  Gems & Jade                  Royalties  entity
# 77  Gems & Jade                 Sale Split  entity
# 78  Gems & Jade  Emporium Fees / Sale Fees  entity
# 79  Gems & Jade           Supervision Fees  entity
# 80  Gems & Jade                  Royalties  entity
#
# [5 rows x 24 columns]

# %%
company_totals = df_gemsjade.pivot_table(index=['Company_name_cl'], aggfunc='sum')['value_reported']
company_totals = company_totals.to_frame()
company_totals.rename(columns={'value_reported': 'total_payments'}, inplace=True)
company_totals.reset_index(level=0, inplace=True)
company_totals
# Out:
#                                       Company_name_cl  total_payments
# 0            (1.1.1) GEMS & JEWELLERY COMPANY LIMITED    8.420018e+09
# 1                  AUNG HEIN MIN GEMS COMPANY LIMITED    2.196766e+09
# 2                           AYAR JADE COMPANY LIMITED    7.016874e+09
# 3     AYEYAR YADANAR GEMS & JEWELLERY COMPANY LIMITED    1.083479e+09
# 4                          Ever Winner Gems Co., Ltd.    4.459207e+09
# 5                  GREAT GENESIS GEMS COMPANY LIMITED    2.001655e+10
# 6                       JADE MOUNTAIN COMPANY LIMITED    8.592584e+09
# 7   KHIN ZAW AUNG & BROTHERS GEMS AND JEWELLERY CO...    4.186186e+09
# 8           KYAING INTERNATIONAL GEMS COMPANY LIMITED    5.351262e+09
# 9            KYAUK SEINN NAGAR (GEMS) COMPANY LIMITED    9.122210e+09
# 10         LINN LETT WIN YADANAR GEMS COMPANY LIMITED    8.079841e+09
# 11  MYANMAR IMPERIAL JADE (GEMS & JEWELLERY) COMPA...    4.175896e+09
# 12                                     Myanmar Si Thu    8.142193e+09
# 13                            Myat Yamon Gems Co.,Ltd    5.778486e+09
# 14           NATIONAL PROSPERITY GEMS COMPANY LIMITED    1.453792e+09
# 15                  NAY LA PWINT GEMS COMPANY LIMITED    4.575571e+09
# 16                       RICHEST GEMS COMPANY LIMITED    1.604481e+10
# 17                       Sein Lom Taung Tan Gems Ltd.    8.686355e+09
# 18      Shining Star Light Gems & Jewellery Co., Ltd.    9.559135e+09
# 19             Shwe Wah Myay (Mandalay)Gems& Co.,Ltd.    1.188666e+09
# 20                     Shwe Ywet Hlwar Gems Co.,.Ltd.    2.083837e+09
# 21      THI RAW MANI GEMS & JEWELLERY COMPANY LIMITED    1.158135e+10
# 22          TREASURE WHITE LOTUS GEMS COMPANY LIMITED    1.007072e+09
# 23                WAI AUNG GABAR GEMS COMPANY LIMITED    1.807804e+10
# 24                    WAI FAMILY GEMS COMPANY LIMITED    1.109455e+09
# 25                   WINN LEI YADANAR COMPANY LIMITED    2.341319e+09
# 26                         XIE FAMILY COMPANY LIMITED    6.365315e+09
# 27            YADANAR TAUNG TANN GEMS COMPANY LIMITED    7.136626e+09
# 28            YANDANAR YAUNG CHI GEMS COMPANY LIMITED    1.893933e+09
# 29                YAR ZA HTAR NE GEMS COMPANY LIMITED    1.279908e+10

# %%
df_gemsjade = pd.merge(df_gemsjade, company_totals, on='Company_name_cl')
df_gemsjade = df_gemsjade.sort_values(by=['total_payments'], ascending=False)

# %%
append_dict_others = [{'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity', 
                       'revenue_stream_short': 'Royalties', 'value_reported': 111092756522 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity', 
                       'revenue_stream_short': 'Sale Split', 'value_reported': 51742994736 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity', 
                       'revenue_stream_short': 'Emporium Fees / Sale Fees', 'value_reported': 11401644588 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity', 
                       'revenue_stream_short': 'Supervision Fees', 'value_reported': 1246890624 },
                      
                     {'Company_name_cl': 'Companies not in EITI Reconciliation', 'type': 'entity', 
                       'revenue_stream_short': 'Other significant payments', 'value_reported': 2186525820 }]

others_df = pd.DataFrame(append_dict_others)
others_df['total_payments'] = others_df['value_reported']
df_gemsjade = pd.concat([df_gemsjade, others_df])
df_gemsjade.tail(10)
# Out:
#      Commodities                                  Company_name_cl  \
# 86   Gems & Jade                  WAI FAMILY GEMS COMPANY LIMITED
# 88   Gems & Jade  AYEYAR YADANAR GEMS & JEWELLERY COMPANY LIMITED
# 87   Gems & Jade  AYEYAR YADANAR GEMS & JEWELLERY COMPANY LIMITED
# 105  Gems & Jade        TREASURE WHITE LOTUS GEMS COMPANY LIMITED
# 106  Gems & Jade        TREASURE WHITE LOTUS GEMS COMPANY LIMITED
# 0            NaN             Others (Not in Reconciliation Scope)
# 1            NaN             Others (Not in Reconciliation Scope)
# 2            NaN             Others (Not in Reconciliation Scope)
# 3            NaN             Others (Not in Reconciliation Scope)
# 4            NaN             Others (Not in Reconciliation Scope)
#
#       Identification Identification_cl                 Legal name  \
# 86   174 / 2000-2001     174/2000-2001            WAI FAMILY GEMS
# 88   1532 /1996-1997    1532/1996-1997       AYEYAR YANDANAR GEMS
# 87   1532 /1996-1997    1532/1996-1997       AYEYAR YANDANAR GEMS
# 105    273/2003-2004     273/2003-2004  TREASURE WHITE LOTUS GEMS
# 106    273/2003-2004     273/2003-2004  TREASURE WHITE LOTUS GEMS
# 0                NaN               NaN                        NaN
# 1                NaN               NaN                        NaN
# 2                NaN               NaN                        NaN
# 3                NaN               NaN                        NaN
# 4                NaN               NaN                        NaN
#
#                       changed               company_name  country  \
# 86   2017-02-13T07:00:42+0000            WAI FAMILY GEMS  Myanmar
# 88   2017-02-13T07:00:42+0000       AYEYAR YANDANAR GEMS  Myanmar
# 87   2017-02-13T07:00:42+0000       AYEYAR YANDANAR GEMS  Myanmar
# 105  2017-02-13T07:00:42+0000  TREASURE WHITE LOTUS GEMS  Myanmar
# 106  2017-02-13T07:00:42+0000  TREASURE WHITE LOTUS GEMS  Myanmar
# 0                         NaN                        NaN      NaN
# 1                         NaN                        NaN      NaN
# 2                         NaN                        NaN      NaN
# 3                         NaN                        NaN      NaN
# 4                         NaN                        NaN      NaN
#
#                       created currency_code   ...    \
# 86   2017-02-13T07:00:42+0000           MMK   ...
# 88   2017-02-13T07:00:42+0000           MMK   ...
# 87   2017-02-13T07:00:42+0000           MMK   ...
# 105  2017-02-13T07:00:42+0000           MMK   ...
# 106  2017-02-13T07:00:42+0000           MMK   ...
# 0                         NaN           NaN   ...
# 1                         NaN           NaN   ...
# 2                         NaN           NaN   ...
# 3                         NaN           NaN   ...
# 4                         NaN           NaN   ...
#
#                                 name_of_revenue_stream  \
# 86   Revenue Stream: 1415E32 [Delivered/paid to sta...
# 88   Revenue Stream: 1415E32 [Delivered/paid to sta...
# 87      Revenue Stream: 1415E1 [Royalties] - Royalties
# 105     Revenue Stream: 1415E1 [Royalties] - Royalties
# 106  Revenue Stream: 1415E32 [Delivered/paid to sta...
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
#                                     reporting_url        revenue_stream_short  \
# 86   https://eiti.org/api/v1.0/organisation/31739   Emporium Fees / Sale Fees
# 88   https://eiti.org/api/v1.0/organisation/31740   Emporium Fees / Sale Fees
# 87   https://eiti.org/api/v1.0/organisation/31740                   Royalties
# 105  https://eiti.org/api/v1.0/organisation/31745                   Royalties
# 106  https://eiti.org/api/v1.0/organisation/31745   Emporium Fees / Sale Fees
# 0                                             NaN                   Royalties
# 1                                             NaN                  Sale Split
# 2                                             NaN   Emporium Fees / Sale Fees
# 3                                             NaN            Supervision Fees
# 4                                             NaN  Other significant payments
#
#       start_date target_type total_payments    type value_reported  \
# 86   Apr 1, 2013               1.109455e+09  entity   9.701789e+07
# 88   Apr 1, 2013               1.083479e+09  entity   8.946155e+07
# 87   Apr 1, 2013               1.083479e+09  entity   9.940174e+08
# 105  Apr 1, 2013               1.007072e+09  entity   9.234732e+08
# 106  Apr 1, 2013               1.007072e+09  entity   8.359920e+07
# 0            NaN         NaN   1.110928e+11  entity   1.110928e+11
# 1            NaN         NaN   5.174299e+10  entity   5.174299e+10
# 2            NaN         NaN   1.140164e+10  entity   1.140164e+10
# 3            NaN         NaN   1.246891e+09  entity   1.246891e+09
# 4            NaN         NaN   2.186526e+09  entity   2.186526e+09
#
#     value_reported_as_USD    year
# 86               101006.0  2014.0
# 88                93139.0  2014.0
# 87              1034883.0  2014.0
# 105              961438.0  2014.0
# 106               87036.0  2014.0
# 0                     NaN     NaN
# 1                     NaN     NaN
# 2                     NaN     NaN
# 3                     NaN     NaN
# 4                     NaN     NaN
#
# [10 rows x 25 columns]

# %%
df_gemsjade['revenue_stream_short'] = df_gemsjade['revenue_stream_short'].replace({'Other significant payments (&gt; 50,000 USD)': 'Other significant payments'})

# %% [markdown]
# ## Remove negative payments for Sankey

# %%
df_gemsjade = df_gemsjade[df_gemsjade["value_reported"] >= 0]

# %% [markdown]
# ## Prepare Source-Target-Value dataframe

# %%
links = pd.DataFrame(columns=['source','target','value','type'])

# %%
to_append = df_gemsjade.groupby(['revenue_stream_short'],as_index=False)['type','value_reported','value_reported_as_USD','total_payments'].sum()
to_append["target"] = "Myanmar Gems Enterprise"
to_append.rename(columns = {'revenue_stream_short':'source', 'value_reported' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['value'], ascending = False)
links = pd.concat([links,to_append])

print(to_append['value'].sum())
links
# Out:
# 380196722113.0
#                        source                   target  total_payments type  \
# 3                  Sale Split  Myanmar Gems Enterprise    2.381985e+11  NaN
# 2                   Royalties  Myanmar Gems Enterprise    3.136187e+11  NaN
# 0   Emporium Fees / Sale Fees  Myanmar Gems Enterprise    2.139276e+11  NaN
# 4            Supervision Fees  Myanmar Gems Enterprise    1.877024e+11  NaN
# 1  Other significant payments  Myanmar Gems Enterprise    4.080459e+09  NaN
#
#           value  value_reported_as_USD
# 3  1.859303e+11            139703870.0
# 2  1.700241e+11             61354119.0
# 0  1.752952e+10              6379800.0
# 4  4.436739e+09              3320985.0
# 1  2.276081e+09                93237.0

# %%
append_dict_transfers = [{'source': 'Myanmar Gems Enterprise', 'type': 'entity',
                       'target': 'State Contribution', 'value': 48367022000 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity', 
                       'target': 'Transfers to Other Accounts', 'value': 195516457782 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity', 
                       'target': 'Commercial Tax', 'value': 21499000 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity', 
                       'target': 'Corporate Income Tax', 'value': 60458777000 },
                         
                         {'source': 'Myanmar Gems Enterprise', 'type': 'entity', 
                       'target': 'Other material transfers', 'value': 119588538585 },
                         
                         {'source': 'State Contribution', 'target_type': 'entity',
                       'target': 'Ministry of Finance', 'value': 48367022000 },
                         
                         {'source': 'Corporate Income Tax', 
                       'target': 'Internal Revenue Department', 'value': 60458777000 },
                         
                         {'source': 'Commercial Tax', 
                       'target': 'Internal Revenue Department', 'value': 21499000 },
                        
                         {'source': 'Internal Revenue Department', 'type': 'entity','target_type': 'entity',
                       'target': 'Ministry of Finance', 'value': 60480276000 }]

append_dict_transfers_df = pd.DataFrame(append_dict_transfers)
links = pd.concat([links, append_dict_transfers_df])
links
# Out:
#                         source                       target target_type  \
# 3                   Sale Split      Myanmar Gems Enterprise         NaN
# 2                    Royalties      Myanmar Gems Enterprise         NaN
# 0    Emporium Fees / Sale Fees      Myanmar Gems Enterprise         NaN
# 4             Supervision Fees      Myanmar Gems Enterprise         NaN
# 1   Other significant payments      Myanmar Gems Enterprise         NaN
# 0      Myanmar Gems Enterprise           State Contribution         NaN
# 1      Myanmar Gems Enterprise  Transfers to Other Accounts         NaN
# 2      Myanmar Gems Enterprise               Commercial Tax         NaN
# 3      Myanmar Gems Enterprise         Corporate Income Tax         NaN
# 4      Myanmar Gems Enterprise     Other material transfers         NaN
# 5           State Contribution          Ministry of Finance      entity
# 6         Corporate Income Tax  Internal Revenue Department         NaN
# 7               Commercial Tax  Internal Revenue Department         NaN
# 8  Internal Revenue Department          Ministry of Finance      entity
#
#    total_payments    type         value  value_reported_as_USD
# 3    2.381985e+11     NaN  1.859303e+11            139703870.0
# 2    3.136187e+11     NaN  1.700241e+11             61354119.0
# 0    2.139276e+11     NaN  1.752952e+10              6379800.0
# 4    1.877024e+11     NaN  4.436739e+09              3320985.0
# 1    4.080459e+09     NaN  2.276081e+09                93237.0
# 0             NaN  entity  4.836702e+10                    NaN
# 1             NaN  entity  1.955165e+11                    NaN
# 2             NaN  entity  2.149900e+07                    NaN
# 3             NaN  entity  6.045878e+10                    NaN
# 4             NaN  entity  1.195885e+11                    NaN
# 5             NaN     NaN  4.836702e+10                    NaN
# 6             NaN     NaN  6.045878e+10                    NaN
# 7             NaN     NaN  2.149900e+07                    NaN
# 8             NaN  entity  6.048028e+10                    NaN

# %%
to_append = df_gemsjade.groupby(['revenue_stream_short','Company_name_cl','type'],as_index=False)['value_reported','value_reported_as_USD','total_payments'].sum()
to_append.rename(columns = {'Company_name_cl':'source','revenue_stream_short':'target', 'value_reported' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['type','total_payments','value'], ascending = False)
links = pd.concat([links,to_append])

print(to_append['value'].sum())
links
# Out:
# 380196722113.0
#                                                 source  \
# 3                                           Sale Split
# 2                                            Royalties
# 0                            Emporium Fees / Sale Fees
# 4                                     Supervision Fees
# 1                           Other significant payments
# 0                              Myanmar Gems Enterprise
# 1                              Myanmar Gems Enterprise
# 2                              Myanmar Gems Enterprise
# 3                              Myanmar Gems Enterprise
# 4                              Myanmar Gems Enterprise
# 5                                   State Contribution
# 6                                 Corporate Income Tax
# 7                                       Commercial Tax
# 8                          Internal Revenue Department
# 49                Others (Not in Reconciliation Scope)
# 77                Others (Not in Reconciliation Scope)
# 67                  GREAT GENESIS GEMS COMPANY LIMITED
# 38                  GREAT GENESIS GEMS COMPANY LIMITED
# 5                   GREAT GENESIS GEMS COMPANY LIMITED
# 91                  GREAT GENESIS GEMS COMPANY LIMITED
# 84                 WAI AUNG GABAR GEMS COMPANY LIMITED
# 57                 WAI AUNG GABAR GEMS COMPANY LIMITED
# 24                 WAI AUNG GABAR GEMS COMPANY LIMITED
# 108                WAI AUNG GABAR GEMS COMPANY LIMITED
# 78                        RICHEST GEMS COMPANY LIMITED
# 50                        RICHEST GEMS COMPANY LIMITED
# 17                        RICHEST GEMS COMPANY LIMITED
# 102                       RICHEST GEMS COMPANY LIMITED
# 87                 YAR ZA HTAR NE GEMS COMPANY LIMITED
# 63                 YAR ZA HTAR NE GEMS COMPANY LIMITED
# ..                                                 ...
# 11   MYANMAR IMPERIAL JADE (GEMS & JEWELLERY) COMPA...
# 59                    WINN LEI YADANAR COMPANY LIMITED
# 26                    WINN LEI YADANAR COMPANY LIMITED
# 34                  AUNG HEIN MIN GEMS COMPANY LIMITED
# 1                   AUNG HEIN MIN GEMS COMPANY LIMITED
# 65                  AUNG HEIN MIN GEMS COMPANY LIMITED
# 89                  AUNG HEIN MIN GEMS COMPANY LIMITED
# 31                Others (Not in Reconciliation Scope)
# 54                      Shwe Ywet Hlwar Gems Co.,.Ltd.
# 21                      Shwe Ywet Hlwar Gems Co.,.Ltd.
# 82                      Shwe Ywet Hlwar Gems Co.,.Ltd.
# 106                     Shwe Ywet Hlwar Gems Co.,.Ltd.
# 62             YANDANAR YAUNG CHI GEMS COMPANY LIMITED
# 29             YANDANAR YAUNG CHI GEMS COMPANY LIMITED
# 32             YANDANAR YAUNG CHI GEMS COMPANY LIMITED
# 75            NATIONAL PROSPERITY GEMS COMPANY LIMITED
# 47            NATIONAL PROSPERITY GEMS COMPANY LIMITED
# 14            NATIONAL PROSPERITY GEMS COMPANY LIMITED
# 99            NATIONAL PROSPERITY GEMS COMPANY LIMITED
# 101               Others (Not in Reconciliation Scope)
# 53              Shwe Wah Myay (Mandalay)Gems& Co.,Ltd.
# 81              Shwe Wah Myay (Mandalay)Gems& Co.,Ltd.
# 20              Shwe Wah Myay (Mandalay)Gems& Co.,Ltd.
# 105             Shwe Wah Myay (Mandalay)Gems& Co.,Ltd.
# 58                     WAI FAMILY GEMS COMPANY LIMITED
# 25                     WAI FAMILY GEMS COMPANY LIMITED
# 36     AYEYAR YADANAR GEMS & JEWELLERY COMPANY LIMITED
# 3      AYEYAR YADANAR GEMS & JEWELLERY COMPANY LIMITED
# 56           TREASURE WHITE LOTUS GEMS COMPANY LIMITED
# 23           TREASURE WHITE LOTUS GEMS COMPANY LIMITED
#
#                           target target_type  total_payments    type  \
# 3        Myanmar Gems Enterprise         NaN    2.381985e+11     NaN
# 2        Myanmar Gems Enterprise         NaN    3.136187e+11     NaN
# 0        Myanmar Gems Enterprise         NaN    2.139276e+11     NaN
# 4        Myanmar Gems Enterprise         NaN    1.877024e+11     NaN
# 1        Myanmar Gems Enterprise         NaN    4.080459e+09     NaN
# 0             State Contribution         NaN             NaN  entity
# 1    Transfers to Other Accounts         NaN             NaN  entity
# 2                 Commercial Tax         NaN             NaN  entity
# 3           Corporate Income Tax         NaN             NaN  entity
# 4       Other material transfers         NaN             NaN  entity
# 5            Ministry of Finance      entity             NaN     NaN
# 6    Internal Revenue Department         NaN             NaN     NaN
# 7    Internal Revenue Department         NaN             NaN     NaN
# 8            Ministry of Finance      entity             NaN  entity
# 49                     Royalties         NaN    1.110928e+11  entity
# 77                    Sale Split         NaN    5.174299e+10  entity
# 67                    Sale Split         NaN    2.001655e+10  entity
# 38                     Royalties         NaN    2.001655e+10  entity
# 5      Emporium Fees / Sale Fees         NaN    2.001655e+10  entity
# 91              Supervision Fees         NaN    2.001655e+10  entity
# 84                    Sale Split         NaN    1.807804e+10  entity
# 57                     Royalties         NaN    1.807804e+10  entity
# 24     Emporium Fees / Sale Fees         NaN    1.807804e+10  entity
# 108             Supervision Fees         NaN    1.807804e+10  entity
# 78                    Sale Split         NaN    1.604481e+10  entity
# 50                     Royalties         NaN    1.604481e+10  entity
# 17     Emporium Fees / Sale Fees         NaN    1.604481e+10  entity
# 102             Supervision Fees         NaN    1.604481e+10  entity
# 87                    Sale Split         NaN    1.279908e+10  entity
# 63                     Royalties         NaN    1.279908e+10  entity
# ..                           ...         ...             ...     ...
# 11     Emporium Fees / Sale Fees         NaN    4.175896e+09  entity
# 59                     Royalties         NaN    2.341319e+09  entity
# 26     Emporium Fees / Sale Fees         NaN    2.341319e+09  entity
# 34                     Royalties         NaN    2.196766e+09  entity
# 1      Emporium Fees / Sale Fees         NaN    2.196766e+09  entity
# 65                    Sale Split         NaN    2.196766e+09  entity
# 89              Supervision Fees         NaN    2.196766e+09  entity
# 31    Other significant payments         NaN    2.186526e+09  entity
# 54                     Royalties         NaN    2.083837e+09  entity
# 21     Emporium Fees / Sale Fees         NaN    2.083837e+09  entity
# 82                    Sale Split         NaN    2.083837e+09  entity
# 106             Supervision Fees         NaN    2.083837e+09  entity
# 62                     Royalties         NaN    1.893933e+09  entity
# 29     Emporium Fees / Sale Fees         NaN    1.893933e+09  entity
# 32    Other significant payments         NaN    1.893933e+09  entity
# 75                    Sale Split         NaN    1.453792e+09  entity
# 47                     Royalties         NaN    1.453792e+09  entity
# 14     Emporium Fees / Sale Fees         NaN    1.453792e+09  entity
# 99              Supervision Fees         NaN    1.453792e+09  entity
# 101             Supervision Fees         NaN    1.246891e+09  entity
# 53                     Royalties         NaN    1.188666e+09  entity
# 81                    Sale Split         NaN    1.188666e+09  entity
# 20     Emporium Fees / Sale Fees         NaN    1.188666e+09  entity
# 105             Supervision Fees         NaN    1.188666e+09  entity
# 58                     Royalties         NaN    1.109455e+09  entity
# 25     Emporium Fees / Sale Fees         NaN    1.109455e+09  entity
# 36                     Royalties         NaN    1.083479e+09  entity
# 3      Emporium Fees / Sale Fees         NaN    1.083479e+09  entity
# 56                     Royalties         NaN    1.007072e+09  entity
# 23     Emporium Fees / Sale Fees         NaN    1.007072e+09  entity
#
#             value  value_reported_as_USD
# 3    1.859303e+11            139703870.0
# 2    1.700241e+11             61354119.0
# 0    1.752952e+10              6379800.0
# 4    4.436739e+09              3320985.0
# 1    2.276081e+09                93237.0
# 0    4.836702e+10                    NaN
# 1    1.955165e+11                    NaN
# 2    2.149900e+07                    NaN
# 3    6.045878e+10                    NaN
# 4    1.195885e+11                    NaN
# 5    4.836702e+10                    NaN
# 6    6.045878e+10                    NaN
# 7    2.149900e+07                    NaN
# 8    6.048028e+10                    NaN
# 49   1.110928e+11                    NaN
# 77   5.174299e+10                    NaN
# 67   1.500496e+10             15621836.0
# 38   4.245309e+09              4419839.0
# 5    3.842051e+08               400000.0
# 91   3.820778e+08               397785.0
# 84   1.339731e+10             13948088.0
# 57   3.942465e+09              4104545.0
# 24   4.170156e+08               434160.0
# 108  3.212483e+08               334455.0
# 78   1.210528e+10             12602939.0
# 50   3.306123e+09              3442042.0
# 17   3.363241e+08               350151.0
# 102  2.970860e+08               309300.0
# 87   1.034887e+10             10774326.0
# 63   1.818793e+09              1893566.0
# ..            ...                    ...
# 11   3.447987e+08               358974.0
# 59   2.147999e+09              2236306.0
# 26   1.933199e+08               201268.0
# 34   1.960794e+09              2041405.0
# 1    2.016849e+08               209976.0
# 65   3.339024e+07                34763.0
# 89   8.961113e+05                  933.0
# 31   2.186526e+09                    NaN
# 54   1.812024e+09              1886519.0
# 21   1.694213e+08               176386.0
# 82   9.859892e+07               102652.0
# 106  3.792266e+06                 3948.0
# 62   1.630513e+09              1697545.0
# 29   1.738648e+08               181013.0
# 32   8.955549e+07                93237.0
# 75   1.105682e+09              1151138.0
# 47   2.894789e+08               301380.0
# 14   3.257888e+07                33918.0
# 99   2.605310e+07                27124.0
# 101  1.246891e+09                    NaN
# 53   8.854260e+08               921827.0
# 81   2.119117e+08               220624.0
# 20   8.556557e+07                89083.0
# 105  5.763085e+06                 6000.0
# 58   1.012437e+09              1054060.0
# 25   9.701789e+07               101006.0
# 36   9.940174e+08              1034883.0
# 3    8.946155e+07                93139.0
# 56   9.234732e+08               961438.0
# 23   8.359920e+07                87036.0
#
# [126 rows x 7 columns]

# %%
#to_append = df.groupby(['Payment Type','Reporting Company'],as_index=False)['Value (USD)'].sum()
#to_append.rename(columns = {'Payment Type':'source','Reporting Company':'target', 'Value (USD)' : 'value'}, inplace = True)
#to_append = to_append.sort_values(by=['value'], ascending = False)
#links = pd.concat([links,to_append])

#print(to_append['value'].sum())
#links

# %%
unique_source = links['source'].unique()
unique_targets = links['target'].unique()

unique_source = pd.merge(pd.DataFrame(unique_source), links, left_on=0, right_on='source', how='left')
unique_source = unique_source.filter([0,'type'])
unique_targets = pd.merge(pd.DataFrame(unique_targets), links, left_on=0, right_on='target', how='left')
unique_targets = unique_targets.filter([0,'target_type'])
unique_targets.rename(columns = {'target_type':'type'}, inplace = True)

unique_list = pd.concat([unique_source[0], unique_targets[0]]).unique()

unique_list = pd.merge(pd.DataFrame(unique_list), \
                       pd.concat([unique_source, unique_targets]), left_on=0, right_on=0, how='left')

unique_list.drop_duplicates(subset=0, keep='first', inplace=True)

replace_dict = {k: v for v, k in enumerate(unique_list[0])}
unique_list
#replace_dict
# Out:
#                                                      0    type
# 0                                           Sale Split     NaN
# 25                                           Royalties     NaN
# 57                           Emporium Fees / Sale Fees     NaN
# 89                                    Supervision Fees     NaN
# 114                         Other significant payments     NaN
# 117                            Myanmar Gems Enterprise  entity
# 127                                 State Contribution     NaN
# 129                               Corporate Income Tax     NaN
# 131                                     Commercial Tax     NaN
# 133                        Internal Revenue Department  entity
# 136               Others (Not in Reconciliation Scope)  entity
# 141                 GREAT GENESIS GEMS COMPANY LIMITED  entity
# 145                WAI AUNG GABAR GEMS COMPANY LIMITED  entity
# 149                       RICHEST GEMS COMPANY LIMITED  entity
# 153                YAR ZA HTAR NE GEMS COMPANY LIMITED  entity
# 157      THI RAW MANI GEMS & JEWELLERY COMPANY LIMITED  entity
# 161      Shining Star Light Gems & Jewellery Co., Ltd.  entity
# 165           KYAUK SEINN NAGAR (GEMS) COMPANY LIMITED  entity
# 169                       Sein Lom Taung Tan Gems Ltd.  entity
# 173                      JADE MOUNTAIN COMPANY LIMITED  entity
# 177           (1.1.1) GEMS & JEWELLERY COMPANY LIMITED  entity
# 181                                     Myanmar Si Thu  entity
# 185         LINN LETT WIN YADANAR GEMS COMPANY LIMITED  entity
# 189            YADANAR TAUNG TANN GEMS COMPANY LIMITED  entity
# 193                          AYAR JADE COMPANY LIMITED  entity
# 197                         XIE FAMILY COMPANY LIMITED  entity
# 201                            Myat Yamon Gems Co.,Ltd  entity
# 205          KYAING INTERNATIONAL GEMS COMPANY LIMITED  entity
# 209                  NAY LA PWINT GEMS COMPANY LIMITED  entity
# 213                         Ever Winner Gems Co., Ltd.  entity
# 215  KHIN ZAW AUNG & BROTHERS GEMS AND JEWELLERY CO...  entity
# 219  MYANMAR IMPERIAL JADE (GEMS & JEWELLERY) COMPA...  entity
# 221                   WINN LEI YADANAR COMPANY LIMITED  entity
# 223                 AUNG HEIN MIN GEMS COMPANY LIMITED  entity
# 227                     Shwe Ywet Hlwar Gems Co.,.Ltd.  entity
# 231            YANDANAR YAUNG CHI GEMS COMPANY LIMITED  entity
# 234           NATIONAL PROSPERITY GEMS COMPANY LIMITED  entity
# 238             Shwe Wah Myay (Mandalay)Gems& Co.,Ltd.  entity
# 242                    WAI FAMILY GEMS COMPANY LIMITED  entity
# 244    AYEYAR YADANAR GEMS & JEWELLERY COMPANY LIMITED  entity
# 246          TREASURE WHITE LOTUS GEMS COMPANY LIMITED  entity
# 248                        Transfers to Other Accounts     NaN
# 249                           Other material transfers     NaN
# 250                                Ministry of Finance  entity

# %%
links_replaced = links.replace({"source": replace_dict,"target": replace_dict})

# %%
links_replaced
# Out:
#      source  target target_type  total_payments    type         value  \
# 3         0       5         NaN    2.381985e+11     NaN  1.859303e+11
# 2         1       5         NaN    3.136187e+11     NaN  1.700241e+11
# 0         2       5         NaN    2.139276e+11     NaN  1.752952e+10
# 4         3       5         NaN    1.877024e+11     NaN  4.436739e+09
# 1         4       5         NaN    4.080459e+09     NaN  2.276081e+09
# 0         5       6         NaN             NaN  entity  4.836702e+10
# 1         5      41         NaN             NaN  entity  1.955165e+11
# 2         5       8         NaN             NaN  entity  2.149900e+07
# 3         5       7         NaN             NaN  entity  6.045878e+10
# 4         5      42         NaN             NaN  entity  1.195885e+11
# 5         6      43      entity             NaN     NaN  4.836702e+10
# 6         7       9         NaN             NaN     NaN  6.045878e+10
# 7         8       9         NaN             NaN     NaN  2.149900e+07
# 8         9      43      entity             NaN  entity  6.048028e+10
# 49       10       1         NaN    1.110928e+11  entity  1.110928e+11
# 77       10       0         NaN    5.174299e+10  entity  5.174299e+10
# 67       11       0         NaN    2.001655e+10  entity  1.500496e+10
# 38       11       1         NaN    2.001655e+10  entity  4.245309e+09
# 5        11       2         NaN    2.001655e+10  entity  3.842051e+08
# 91       11       3         NaN    2.001655e+10  entity  3.820778e+08
# 84       12       0         NaN    1.807804e+10  entity  1.339731e+10
# 57       12       1         NaN    1.807804e+10  entity  3.942465e+09
# 24       12       2         NaN    1.807804e+10  entity  4.170156e+08
# 108      12       3         NaN    1.807804e+10  entity  3.212483e+08
# 78       13       0         NaN    1.604481e+10  entity  1.210528e+10
# 50       13       1         NaN    1.604481e+10  entity  3.306123e+09
# 17       13       2         NaN    1.604481e+10  entity  3.363241e+08
# 102      13       3         NaN    1.604481e+10  entity  2.970860e+08
# 87       14       0         NaN    1.279908e+10  entity  1.034887e+10
# 63       14       1         NaN    1.279908e+10  entity  1.818793e+09
# ..      ...     ...         ...             ...     ...           ...
# 11       31       2         NaN    4.175896e+09  entity  3.447987e+08
# 59       32       1         NaN    2.341319e+09  entity  2.147999e+09
# 26       32       2         NaN    2.341319e+09  entity  1.933199e+08
# 34       33       1         NaN    2.196766e+09  entity  1.960794e+09
# 1        33       2         NaN    2.196766e+09  entity  2.016849e+08
# 65       33       0         NaN    2.196766e+09  entity  3.339024e+07
# 89       33       3         NaN    2.196766e+09  entity  8.961113e+05
# 31       10       4         NaN    2.186526e+09  entity  2.186526e+09
# 54       34       1         NaN    2.083837e+09  entity  1.812024e+09
# 21       34       2         NaN    2.083837e+09  entity  1.694213e+08
# 82       34       0         NaN    2.083837e+09  entity  9.859892e+07
# 106      34       3         NaN    2.083837e+09  entity  3.792266e+06
# 62       35       1         NaN    1.893933e+09  entity  1.630513e+09
# 29       35       2         NaN    1.893933e+09  entity  1.738648e+08
# 32       35       4         NaN    1.893933e+09  entity  8.955549e+07
# 75       36       0         NaN    1.453792e+09  entity  1.105682e+09
# 47       36       1         NaN    1.453792e+09  entity  2.894789e+08
# 14       36       2         NaN    1.453792e+09  entity  3.257888e+07
# 99       36       3         NaN    1.453792e+09  entity  2.605310e+07
# 101      10       3         NaN    1.246891e+09  entity  1.246891e+09
# 53       37       1         NaN    1.188666e+09  entity  8.854260e+08
# 81       37       0         NaN    1.188666e+09  entity  2.119117e+08
# 20       37       2         NaN    1.188666e+09  entity  8.556557e+07
# 105      37       3         NaN    1.188666e+09  entity  5.763085e+06
# 58       38       1         NaN    1.109455e+09  entity  1.012437e+09
# 25       38       2         NaN    1.109455e+09  entity  9.701789e+07
# 36       39       1         NaN    1.083479e+09  entity  9.940174e+08
# 3        39       2         NaN    1.083479e+09  entity  8.946155e+07
# 56       40       1         NaN    1.007072e+09  entity  9.234732e+08
# 23       40       2         NaN    1.007072e+09  entity  8.359920e+07
#
#      value_reported_as_USD
# 3              139703870.0
# 2               61354119.0
# 0                6379800.0
# 4                3320985.0
# 1                  93237.0
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 49                     NaN
# 77                     NaN
# 67              15621836.0
# 38               4419839.0
# 5                 400000.0
# 91                397785.0
# 84              13948088.0
# 57               4104545.0
# 24                434160.0
# 108               334455.0
# 78              12602939.0
# 50               3442042.0
# 17                350151.0
# 102               309300.0
# 87              10774326.0
# 63               1893566.0
# ..                     ...
# 11                358974.0
# 59               2236306.0
# 26                201268.0
# 34               2041405.0
# 1                 209976.0
# 65                 34763.0
# 89                   933.0
# 31                     NaN
# 54               1886519.0
# 21                176386.0
# 82                102652.0
# 106                 3948.0
# 62               1697545.0
# 29                181013.0
# 32                 93237.0
# 75               1151138.0
# 47                301380.0
# 14                 33918.0
# 99                 27124.0
# 101                    NaN
# 53                921827.0
# 81                220624.0
# 20                 89083.0
# 105                 6000.0
# 58               1054060.0
# 25                101006.0
# 36               1034883.0
# 3                  93139.0
# 56                961438.0
# 23                 87036.0
#
# [126 rows x 7 columns]

# %%
nodes = pd.DataFrame(unique_list)
nodes.rename(columns = {0:'name'}, inplace = True)

# %%
nodes_json= pd.DataFrame(nodes).to_json(orient='records')
nodes_json
# Out:
# '[{"name":"Sale Split","type":null},{"name":"Royalties","type":null},{"name":"Emporium Fees \\/ Sale Fees","type":null},{"name":"Supervision Fees","type":null},{"name":"Other significant payments","type":null},{"name":"Myanmar Gems Enterprise","type":"entity"},{"name":"State Contribution","type":null},{"name":"Corporate Income Tax","type":null},{"name":"Commercial Tax","type":null},{"name":"Internal Revenue Department","type":"entity"},{"name":"Others (Not in Reconciliation Scope)","type":"entity"},{"name":"GREAT GENESIS GEMS COMPANY LIMITED","type":"entity"},{"name":"WAI AUNG GABAR GEMS COMPANY LIMITED","type":"entity"},{"name":"RICHEST GEMS COMPANY LIMITED","type":"entity"},{"name":"YAR ZA HTAR NE GEMS COMPANY LIMITED","type":"entity"},{"name":"THI RAW MANI GEMS & JEWELLERY COMPANY LIMITED","type":"entity"},{"name":"Shining Star Light Gems & Jewellery Co., Ltd.","type":"entity"},{"name":"KYAUK SEINN NAGAR (GEMS) COMPANY LIMITED","type":"entity"},{"name":"Sein Lom Taung Tan Gems Ltd.","type":"entity"},{"name":"JADE MOUNTAIN COMPANY LIMITED","type":"entity"},{"name":"(1.1.1) GEMS & JEWELLERY COMPANY LIMITED","type":"entity"},{"name":"Myanmar Si Thu","type":"entity"},{"name":"LINN LETT WIN YADANAR GEMS COMPANY LIMITED","type":"entity"},{"name":"YADANAR TAUNG TANN GEMS COMPANY LIMITED","type":"entity"},{"name":"AYAR JADE COMPANY LIMITED","type":"entity"},{"name":"XIE FAMILY COMPANY LIMITED","type":"entity"},{"name":"Myat Yamon Gems Co.,Ltd","type":"entity"},{"name":"KYAING INTERNATIONAL GEMS COMPANY LIMITED","type":"entity"},{"name":"NAY LA PWINT GEMS COMPANY LIMITED","type":"entity"},{"name":"Ever Winner Gems Co., Ltd.","type":"entity"},{"name":"KHIN ZAW AUNG & BROTHERS GEMS AND JEWELLERY COMPANY LIMITED","type":"entity"},{"name":"MYANMAR IMPERIAL JADE (GEMS & JEWELLERY) COMPANY LIMITED","type":"entity"},{"name":"WINN LEI YADANAR COMPANY LIMITED","type":"entity"},{"name":"AUNG HEIN MIN GEMS COMPANY LIMITED","type":"entity"},{"name":"Shwe Ywet Hlwar Gems Co.,.Ltd.","type":"entity"},{"name":"YANDANAR YAUNG CHI GEMS COMPANY LIMITED","type":"entity"},{"name":"NATIONAL PROSPERITY GEMS COMPANY LIMITED","type":"entity"},{"name":"Shwe Wah Myay (Mandalay)Gems& Co.,Ltd.","type":"entity"},{"name":"WAI FAMILY GEMS COMPANY LIMITED","type":"entity"},{"name":"AYEYAR YADANAR GEMS & JEWELLERY COMPANY LIMITED","type":"entity"},{"name":"TREASURE WHITE LOTUS GEMS COMPANY LIMITED","type":"entity"},{"name":"Transfers to Other Accounts","type":null},{"name":"Other material transfers","type":null},{"name":"Ministry of Finance","type":"entity"}]'

# %%
links_json= pd.DataFrame(links_replaced).to_json(orient='records')
links_json
# Out:
# '[{"source":0,"target":5,"target_type":null,"total_payments":238198542926.6718139648,"type":null,"value":185930251282.5733642578,"value_reported_as_USD":139703870.0},{"source":1,"target":5,"target_type":null,"total_payments":313618666344.5166015625,"type":null,"value":170024130471.1452636719,"value_reported_as_USD":61354119.0},{"source":2,"target":5,"target_type":null,"total_payments":213927554410.5165710449,"type":null,"value":17529519654.9551620483,"value_reported_as_USD":6379800.0},{"source":3,"target":5,"target_type":null,"total_payments":187702438814.6718139648,"type":null,"value":4436739393.4279022217,"value_reported_as_USD":3320985.0},{"source":4,"target":5,"target_type":null,"total_payments":4080458833.2069458961,"type":null,"value":2276081310.4148459435,"value_reported_as_USD":93237.0},{"source":5,"target":6,"target_type":null,"total_payments":null,"type":"entity","value":48367022000.0,"value_reported_as_USD":null},{"source":5,"target":41,"target_type":null,"total_payments":null,"type":"entity","value":195516457782.0,"value_reported_as_USD":null},{"source":5,"target":8,"target_type":null,"total_payments":null,"type":"entity","value":21499000.0,"value_reported_as_USD":null},{"source":5,"target":7,"target_type":null,"total_payments":null,"type":"entity","value":60458777000.0,"value_reported_as_USD":null},{"source":5,"target":42,"target_type":null,"total_payments":null,"type":"entity","value":119588538585.0,"value_reported_as_USD":null},{"source":6,"target":43,"target_type":"entity","total_payments":null,"type":null,"value":48367022000.0,"value_reported_as_USD":null},{"source":7,"target":9,"target_type":null,"total_payments":null,"type":null,"value":60458777000.0,"value_reported_as_USD":null},{"source":8,"target":9,"target_type":null,"total_payments":null,"type":null,"value":21499000.0,"value_reported_as_USD":null},{"source":9,"target":43,"target_type":"entity","total_payments":null,"type":"entity","value":60480276000.0,"value_reported_as_USD":null},{"source":10,"target":1,"target_type":null,"total_payments":111092756522.0,"type":"entity","value":111092756522.0,"value_reported_as_USD":null},{"source":10,"target":0,"target_type":null,"total_payments":51742994736.0,"type":"entity","value":51742994736.0,"value_reported_as_USD":null},{"source":11,"target":0,"target_type":null,"total_payments":20016553974.3760375977,"type":"entity","value":15004962403.7789993286,"value_reported_as_USD":15621836.0},{"source":11,"target":1,"target_type":null,"total_payments":20016553974.3760375977,"type":"entity","value":4245308740.3607001305,"value_reported_as_USD":4419839.0},{"source":11,"target":2,"target_type":null,"total_payments":20016553974.3760375977,"type":"entity","value":384205066.7981700301,"value_reported_as_USD":400000.0},{"source":11,"target":3,"target_type":null,"total_payments":20016553974.3760375977,"type":"entity","value":382077763.4381700158,"value_reported_as_USD":397785.0},{"source":12,"target":0,"target_type":null,"total_payments":18078036756.103313446,"type":"entity","value":13397307541.9280014038,"value_reported_as_USD":13948088.0},{"source":12,"target":1,"target_type":null,"total_payments":18078036756.103313446,"type":"entity","value":3942465305.63560009,"value_reported_as_USD":4104545.0},{"source":12,"target":2,"target_type":null,"total_payments":18078036756.103313446,"type":"entity","value":417015613.1557700038,"value_reported_as_USD":434160.0},{"source":12,"target":3,"target_type":null,"total_payments":18078036756.103313446,"type":"entity","value":321248295.3839399815,"value_reported_as_USD":334455.0},{"source":13,"target":0,"target_type":null,"total_payments":16044808582.2006378174,"type":"entity","value":12105275122.6339988708,"value_reported_as_USD":12602939.0},{"source":13,"target":1,"target_type":null,"total_payments":16044808582.2006378174,"type":"entity","value":3306123319.1367998123,"value_reported_as_USD":3442042.0},{"source":13,"target":2,"target_type":null,"total_payments":16044808582.2006378174,"type":"e ...

# %%
data = { 'links' : json.loads(links_json), 'nodes' : json.loads(nodes_json) }
data_json = json.dumps(data)
data_json = data_json.replace("\\","")
#print(data_json)
#with open('sankey_data.json', 'w') as outfile:
#    json.dump(data_json, outfile)

text_file = open("sankey_data_2013-14.json", "w")
text_file.write(data_json)
text_file.close()
