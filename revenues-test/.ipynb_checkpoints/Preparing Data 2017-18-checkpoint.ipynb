# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_csv('data/2017-18/2017-18_gems_jade.csv')

# %%
# df = df[df['country'] == "Myanmar"]

# %%
df.head()
# Out:
#    Unnamed: 0                       company_name      name_of_revenue_stream  \
# 0           0  Linn Lett Win Yadanar Gems Co Ltd  Production Split (In Kind)
# 1           0  Linn Lett Win Yadanar Gems Co Ltd              Customs Duties
# 2           0  Linn Lett Win Yadanar Gems Co Ltd   Commercial Tax on Imports
# 3           0  Linn Lett Win Yadanar Gems Co Ltd        Corporate Income Tax
# 4           0  Linn Lett Win Yadanar Gems Co Ltd    Specific Goods Tax (MCD)
#
#    value_reported                        paid_to
# 0            0.00  Myanmar Gems Enterprise (MGE)
# 1     13855086.18       MoF - Customs Department
# 2            0.00       MoF - Customs Department
# 3            0.00       MoF - Customs Department
# 4            0.00       MoF - Customs Department

# %% [markdown]
# ## Clean data

# %%
df_gemsjade = df

df_gemsjade.rename(columns={'company_name': 'Company_name_cl', 'per_government_final': 'value_reported'}, inplace=True)

df_gemsjade['type'] = 'entity'
df_gemsjade['target_type'] = ''

# %%
df_gemsjade.head()
# Out:
#    Unnamed: 0                    Company_name_cl      name_of_revenue_stream  \
# 0           0  Linn Lett Win Yadanar Gems Co Ltd  Production Split (In Kind)
# 1           0  Linn Lett Win Yadanar Gems Co Ltd              Customs Duties
# 2           0  Linn Lett Win Yadanar Gems Co Ltd   Commercial Tax on Imports
# 3           0  Linn Lett Win Yadanar Gems Co Ltd        Corporate Income Tax
# 4           0  Linn Lett Win Yadanar Gems Co Ltd    Specific Goods Tax (MCD)
#
#    value_reported                        paid_to    type target_type
# 0            0.00  Myanmar Gems Enterprise (MGE)  entity
# 1     13855086.18       MoF - Customs Department  entity
# 2            0.00       MoF - Customs Department  entity
# 3            0.00       MoF - Customs Department  entity
# 4            0.00       MoF - Customs Department  entity

# %%
## Page 208-209 of 2016-17 Report. 3.5.2. Government receipts from companies not selected in the reconciliation scope

append_dict_others = [
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Internal Revenue Department (IRD)','name_of_revenue_stream':'Corporate Income Tax','type':'entity','value_reported':2360822372},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Internal Revenue Department (IRD)','name_of_revenue_stream':'Commercial Tax','type':'entity','value_reported':2934006762},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Internal Revenue Department (IRD)','name_of_revenue_stream':'Capital Gains Tax','type':'entity','value_reported':31651554},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Internal Revenue Department (IRD)','name_of_revenue_stream':'Withholding tax - Resident','type':'entity','value_reported':36000000},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Internal Revenue Department (IRD)','name_of_revenue_stream':'Withholding tax - Non-Resident','type':'entity','value_reported':0},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Internal Revenue Department (IRD)','name_of_revenue_stream':'Stamp Duties','type':'entity','value_reported':0},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Internal Revenue Department (IRD)','name_of_revenue_stream':'Specific Goods Tax','type':'entity','value_reported':14632620504},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Internal Revenue Department (IRD)','name_of_revenue_stream':'Personal Income Tax','type':'entity','value_reported':0},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Customs Department','name_of_revenue_stream':'Custom duty','type':'entity','value_reported':1915077930},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Customs Department','name_of_revenue_stream':'Commercial Tax on Imported Capital Equipment','type':'entity','value_reported':3628738468},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Customs Department','name_of_revenue_stream':'Commercial Tax on Imports on Raw Materials and Inventories','type':'entity','value_reported':0},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Department of Mines (DOM)','name_of_revenue_stream':'Royalties on Production - Raw Materials 20%, Added Value 10%','type':'entity','value_reported':8418317757},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Forest Department','name_of_revenue_stream':'Land Fee','type':'entity','value_reported':600000},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Forest Department','name_of_revenue_stream':'Environmental/Plantation Fee','type':'entity','value_reported':0},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Commercial Tax - 5% (MMK)','type':'entity','value_reported':1857358515},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Commercial Tax - 15% (MMK)','type':'entity','value_reported':158774212},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Specific Goods Tax - Rough Stones 20%, Jewellery 5%','type':'entity','value_reported':33470163309},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Production Split - 25% of sales net of Tax','type':'entity','value_reported':2702274313},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Service Fees Euro Sales - Raw Materials 3%, Added Value 1%','type':'entity','value_reported':6055762841},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Supervision Fees for Euro Sales','type':'entity','value_reported':138220135},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Central Committee 1% on sales','type':'entity','value_reported':10564524},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Penalty (Central Committee 1%)','type':'entity','value_reported':467952318},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Penalty (Supervision Fees)','type':'entity','value_reported':40959801},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Penalty 10%','type':'entity','value_reported':1143456276},
{'Company_name_cl':'Companies not in EITI Reconciliation','paid_to':'Myanmar Gems Enterprise','name_of_revenue_stream':'Penalty 25%','type':'entity','value_reported':887716624},
]

others_df = pd.DataFrame(append_dict_others)
#others_df['total_payments'] = others_df['value_reported']
df_gemsjade = pd.concat([df_gemsjade, others_df])
df_gemsjade.tail(30)
# Out:
#       Unnamed: 0                       Company_name_cl  \
# 2263      2263.0               Zebu Thiri Gems Co.,Ltd
# 2264      2264.0               Zebu Thiri Gems Co.,Ltd
# 2265      2265.0               Zebu Thiri Gems Co.,Ltd
# 2266      2266.0               Zebu Thiri Gems Co.,Ltd
# 2267      2267.0               Zebu Thiri Gems Co.,Ltd
# 0            NaN  Companies not in EITI Reconciliation
# 1            NaN  Companies not in EITI Reconciliation
# 2            NaN  Companies not in EITI Reconciliation
# 3            NaN  Companies not in EITI Reconciliation
# 4            NaN  Companies not in EITI Reconciliation
# 5            NaN  Companies not in EITI Reconciliation
# 6            NaN  Companies not in EITI Reconciliation
# 7            NaN  Companies not in EITI Reconciliation
# 8            NaN  Companies not in EITI Reconciliation
# 9            NaN  Companies not in EITI Reconciliation
# 10           NaN  Companies not in EITI Reconciliation
# ...

# %%
df_gemsjade['name_of_revenue_stream'] = df_gemsjade['name_of_revenue_stream'].replace({'Other significant payments (&gt; 50,000 USD)': 'Other significant payments (> 50,000 USD)'})

df_gemsjade['paid_to'] = df_gemsjade['paid_to'].replace({'Myanma Gems Enterprise': 'Myanmar Gems Enterprise'})

df_gemsjade['paid_to'] = df_gemsjade['paid_to'].str.strip()

# %%
df_gemsjade['paid_to'].unique()
# Out:
# array(['State Owned Enterprises (ME1, ME2)', 'Customs Department (CD)',
#        'Internal Revenue Department (IRD)', 'Department of Mines (DOM)',
#        'Forest Department', 'Myanmar Gems Enterprise',
#        'Ministry of Labour', 'State/Regions (Subnational Government)',
#        'CSR Beneficiaries', 'Customs Department'], dtype=object)

# %%
company_totals = df_gemsjade.pivot_table(index=['Company_name_cl'], aggfunc='sum')['value_reported']
company_totals = company_totals.to_frame()
company_totals.rename(columns={'value_reported': 'total_payments'}, inplace=True)
company_totals.reset_index(level=0, inplace=True)
company_totals.sort_values(by=['total_payments'], ascending = False, inplace=True)
company_totals
# Out:
#                                       Company_name_cl  total_payments
# 10               Companies not in EITI Reconciliation    8.089104e+10
# 39                         Linn Lett Win Yadanar Gems    2.566183e+10
# 33  Khin Zaw Aung & Brothers Gems and Jewellery Co...    2.548483e+10
# 81                   Yadanar Taung Tann Gems Co.,Ltd.    2.058370e+10
# 67                     Shwe Byain Phyu (Gems) Company    2.045180e+10
# ..                                                ...             ...
# 26      Jade Pioneer Company Limited (Jade Shaesaung)    4.092383e+07
# 18                                         Great Nine    1.346422e+07
# 50                               Myat Myitta Mon Gems    0.000000e+00
# 23                Jade New Gems & Jewellery Co., Ltd.    0.000000e+00
# 7    CANCRI (GEMS & Jewellery) Co.,Ltd (Phu Sha Star)    0.000000e+00
#
# [85 rows x 2 columns]

# %%
df_gemsjade = pd.merge(df_gemsjade, company_totals, on='Company_name_cl')

# %% [markdown]
# ## Remove negative payments for Sankey

# %%
df_gemsjade = df_gemsjade[df_gemsjade["value_reported"] > 0]
df_gemsjade = df_gemsjade.sort_values(by=['total_payments'], ascending=False)
df_gemsjade.drop(['Unnamed: 0'], axis=1)
df_gemsjade
# Out:
#       Unnamed: 0                                Company_name_cl  \
# 2292         NaN           Companies not in EITI Reconciliation
# 2282         NaN           Companies not in EITI Reconciliation
# 2268         NaN           Companies not in EITI Reconciliation
# 2269         NaN           Companies not in EITI Reconciliation
# 2271         NaN           Companies not in EITI Reconciliation
# ...          ...                                            ...
# 667        667.0  Jade Pioneer Company Limited (Jade Shaesaung)
# 663        663.0  Jade Pioneer Company Limited (Jade Shaesaung)
# 451        451.0                                     Great Nine
# 444        444.0                                     Great Nine
# 442        442.0                                     Great Nine
#
#      company_registration_number  \
# 2292                         NaN
# 2282                         NaN
# 2268                         NaN
# 2269                         NaN
# ...

# %%
df_gemsjade_summary = df_gemsjade[df_gemsjade['Company_name_cl'] != 'Companies not in EITI Reconciliation']
df_gemsjade_summary = df_gemsjade_summary.groupby(['name_of_revenue_stream','paid_to','target_type','type']).sum().reset_index()
df_gemsjade_summary['Company_name_cl'] = 'Companies in EITI Reconciliation'
df_gemsjade_summary = df_gemsjade[df_gemsjade['Company_name_cl'] == 'Companies not in EITI Reconciliation'] \
                        .append(df_gemsjade_summary)
df_gemsjade_summary
# Out:
#       Unnamed: 0                       Company_name_cl  \
# 2292         NaN  Companies not in EITI Reconciliation
# 2282         NaN  Companies not in EITI Reconciliation
# 2268         NaN  Companies not in EITI Reconciliation
# 2269         NaN  Companies not in EITI Reconciliation
# 2271         NaN  Companies not in EITI Reconciliation
# 2274         NaN  Companies not in EITI Reconciliation
# 2276         NaN  Companies not in EITI Reconciliation
# 2277         NaN  Companies not in EITI Reconciliation
# 2279         NaN  Companies not in EITI Reconciliation
# 2280         NaN  Companies not in EITI Reconciliation
# 2270         NaN  Companies not in EITI Reconciliation
# 2283         NaN  Companies not in EITI Reconciliation
# 2285         NaN  Companies not in EITI Reconciliation
# 2286         NaN  Companies not in EITI Reconciliation
# 2287         NaN  Companies not in EITI Reconciliation
# 2288         NaN  Companies not in EITI Reconciliation
# ...

# %% [markdown]
# ## Prepare Source-Target-Value dataframe

# %%
links_companies = pd.DataFrame(columns=['source','target','value','type'])

# %%
to_append = df_gemsjade.groupby(['name_of_revenue_stream','paid_to'],as_index=False)['type','value_reported','total_payments'].sum()

#to_append["target"] = "Myanmar Gems Enterprise"
to_append.rename(columns = {'name_of_revenue_stream':'source', 'value_reported' : 'value', 'paid_to': 'target'}, inplace = True)

to_append = to_append.sort_values(by=['value'], ascending = False)
to_append['target_type'] = 'entity'

links_companies = pd.concat([links_companies,to_append])

print(to_append['value'].sum())
links_companies
# Out:
# 362759156756.86273
# <ipython-input-15-7397dd4ad5fc>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   to_append = df_gemsjade.groupby(['name_of_revenue_stream','paid_to'],as_index=False)['type','value_reported','total_payments'].sum()
#                                                source  \
# 19                                 Specific Goods Tax
# 16         Production Split - 25% of sales net of Tax
# 20  Specific Goods Tax - Rough Stones 20%, Jewelle...
# 18  Service Fees Euro Sales - Raw Materials 3%, Ad...
# 17  Royalties on Production - Raw Materials 20%, A...
# 2                                      Commercial Tax
# 8                                Corporate Income Tax
# 5        Commercial Tax on Imported Capital Equipment
# 4                           Commercial Tax - 5% (MMK)
# 22                    Supervision Fees for Euro Sales
# 6        Commercial Tax on Imported Capital Equipment
# ...

# %%
## Page 88 of 2016-17 Report. Table 29 Transfer from SOEs to Government Agencies in FY 2016-2017
## and from Appendix 8: SOE Reconciliation Sheets

append_dict_transfers = [
{'source':'Myanmar Gems Enterprise','type':'entiity','target_type':'','target':'Corporate Income Tax ','value':38919409000},
{'source':'Myanmar Gems Enterprise','type':'entiity','target_type':'','target':'Commercial Tax - MGE sales ','value':2968993},
{'source':'Myanmar Gems Enterprise','type':'entiity','target_type':'','target':'Specific Goods Tax - Rough Stones 20%, Jewellery 5% (MGE Sales) ','value':137000000},
{'source':'Myanmar Gems Enterprise','type':'entiity','target_type':'','target':'State Contribution ','value':31135527000},
{'source':'Myanmar Gems Enterprise','type':'entiity','target_type':'','target':'Transfer to Other Account','value':50155955000},
{'source':'Myanmar Gems Enterprise','type':'entiity','target_type':'entiity','target':'Central Committee','value':485000000},
{'source':'Corporate Income Tax ','type':'entiity','target_type':'entiity','target':'MoPF-Internal Revenue Department','value':38919409000},
{'source':'Commercial Tax - MGE sales ','type':'entiity','target_type':'entiity','target':'MoPF-Internal Revenue Department','value':2968993},
{'source':'Specific Goods Tax - Rough Stones 20%, Jewellery 5% (MGE Sales) ','type':'entiity','target_type':'entiity','target':'MoPF-Internal Revenue Department','value':137000000},
{'source':'State Contribution ','type':'entiity','target_type':'entiity','target':'MoPF-Treasury and Budget','value':31135527000},
]



append_dict_transfers_df = pd.DataFrame(append_dict_transfers)

links_summary = pd.concat([links_companies, append_dict_transfers_df])
links_govt = append_dict_transfers_df
#links = pd.concat([links, append_dict_transfers_df])

# %%
to_append = df_gemsjade.groupby(['name_of_revenue_stream','Company_name_cl','type'],as_index=False) \
    ['value_reported','total_payments'] \
    .agg({'value_reported':sum,'total_payments':'first'})
to_append.rename(columns = {'Company_name_cl':'source','name_of_revenue_stream':'target', 'value_reported' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['total_payments'], ascending = False)
links_companies = pd.concat([links_companies,to_append])

print(to_append['value'].sum())
#links
to_append
# Out:
# 362759156756.86273
# <ipython-input-17-12b8b8549258>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   to_append = df_gemsjade.groupby(['name_of_revenue_stream','Company_name_cl','type'],as_index=False) \
#                                                 target  \
# 0                                    Capital Gains Tax
# 465                                 Specific Goods Tax
# 154       Commercial Tax on Imported Capital Equipment
# 254                                        Custom duty
# 255                                           Land Fee
# ..                                                 ...
# 329  Royalties on Production - Raw Materials 20%, A...
# 403  Service Fees Euro Sales - Raw Materials 3%, Ad...
# 397  Service Fees Euro Sales - Raw Materials 3%, Ad...
# 323  Royalties on Production - Raw Materials 20%, A...
# 470                                 Specific Goods Tax
#
# ...

# %%
df_gemsjade_summary
# Out:
#       Unnamed: 0                       Company_name_cl  \
# 2292         NaN  Companies not in EITI Reconciliation
# 2282         NaN  Companies not in EITI Reconciliation
# 2268         NaN  Companies not in EITI Reconciliation
# 2269         NaN  Companies not in EITI Reconciliation
# 2271         NaN  Companies not in EITI Reconciliation
# 2274         NaN  Companies not in EITI Reconciliation
# 2276         NaN  Companies not in EITI Reconciliation
# 2277         NaN  Companies not in EITI Reconciliation
# 2279         NaN  Companies not in EITI Reconciliation
# 2280         NaN  Companies not in EITI Reconciliation
# 2270         NaN  Companies not in EITI Reconciliation
# 2283         NaN  Companies not in EITI Reconciliation
# 2285         NaN  Companies not in EITI Reconciliation
# 2286         NaN  Companies not in EITI Reconciliation
# 2287         NaN  Companies not in EITI Reconciliation
# 2288         NaN  Companies not in EITI Reconciliation
# ...

# %%
to_append = df_gemsjade_summary.groupby(['name_of_revenue_stream','Company_name_cl','type'],as_index=False) \
    ['value_reported','total_payments'] \
    .agg({'value_reported':sum,'total_payments':'first'})
to_append.rename(columns = {'Company_name_cl':'source','name_of_revenue_stream':'target', 'value_reported' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['total_payments'], ascending = False)
display(to_append)
links_summary = pd.concat([links_summary,to_append])
links_summary
# Out:
# <ipython-input-19-6dd3f32b896f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   to_append = df_gemsjade_summary.groupby(['name_of_revenue_stream','Company_name_cl','type'],as_index=False) \
#                                                target  \
# 26  Service Fees Euro Sales - Raw Materials 3%, Ad...
# 24  Royalties on Production - Raw Materials 20%, A...
# 22         Production Split - 25% of sales net of Tax
# 4                                      Commercial Tax
# 13                               Corporate Income Tax
# 33                    Supervision Fees for Euro Sales
# 28                                 Specific Goods Tax
# 6                          Commercial Tax - 15% (MMK)
# 30  Specific Goods Tax - Rough Stones 20%, Jewelle...
# 2                       Central Committee 1% on sales
# 15                                     Custom Duties
# ...

# %%
def prep_nodes_links(links):
    unique_source = links['source'].unique()
    unique_targets = links['target'].unique()

    unique_source = pd.merge(pd.DataFrame(unique_source), links, left_on=0, right_on='source', how='left')
    unique_source = unique_source.filter([0,'type'])
    unique_targets = pd.merge(pd.DataFrame(unique_targets), links, left_on=0, right_on='target', how='left')
    unique_targets = unique_targets.filter([0,'target_type'])
    unique_targets.rename(columns = {'target_type':'type'}, inplace = True)

    unique_list = pd.concat([unique_source[0], unique_targets[0]]).unique()

    unique_list = pd.merge(pd.DataFrame(unique_list), \
                           pd.concat([unique_source, unique_targets]), left_on=0, right_on=0, how='left')

    unique_list.drop_duplicates(subset=0, keep='first', inplace=True)

    replace_dict = {k: v for v, k in enumerate(unique_list[0])}
    unique_list
    return [unique_list,replace_dict]


#unique_list = pd.concat([links['source'], links['target']]).unique()
#replace_dict = {k: v for v, k in enumerate(unique_list)}

# %%
[unique_list_summary,replace_dict_summary] = prep_nodes_links(links_summary)
[unique_list_companies,replace_dict_companies] = prep_nodes_links(links_companies)
[unique_list_govt,replace_dict_govt] = prep_nodes_links(links_govt)

# %%
def write_nodes_links(filename,unique_list,replace_dict,links):
    links_replaced = links.replace({"source": replace_dict,"target": replace_dict})
    nodes = pd.DataFrame(unique_list)
    nodes.rename(columns = {0:'name'}, inplace = True)
    nodes_json= pd.DataFrame(nodes).to_json(orient='records')
    links_json= pd.DataFrame(links_replaced).to_json(orient='records')
    
    data = { 'links' : json.loads(links_json), 'nodes' : json.loads(nodes_json) }
    data_json = json.dumps(data)
    data_json = data_json.replace("\\","")
    #print(data_json)
    #with open('sankey_data.json', 'w') as outfile:
    #    json.dump(data_json, outfile)

    text_file = open(filename + ".json", "w")
    text_file.write(data_json)
    text_file.close()

# %%
write_nodes_links("sankey_data_2016-17_summary",unique_list_summary,replace_dict_summary,links_summary)
write_nodes_links("sankey_data_2016-17_companies",unique_list_companies,replace_dict_companies,links_companies)
write_nodes_links("sankey_data_2016-17_govt",unique_list_govt,replace_dict_govt,links_govt)
